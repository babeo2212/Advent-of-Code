# %%
import re
from pprint import pprint

# %%
with open('input_day7.txt', 'r') as f:
    inputs = f.readlines()

# %%
inputs = [x.strip('\n') for x in inputs]

# %%
inputs[0]
# Out:
# 'striped green bags contain 5 posh indigo bags.'

# %%
pattern = '(\w*\s\w*\sbag)'

# %%
for i in inputs:
    print(re.findall(pattern, i))
# Out:
# ['striped green bag', 'posh indigo bag']
# ['light yellow bag', 'wavy turquoise bag']
# ['bright lime bag', 'striped crimson bag', 'dull red bag']
# ['dull blue bag', 'posh coral bag', 'mirrored coral bag', 'striped fuchsia bag']
# ['vibrant coral bag', 'shiny blue bag', 'muted gray bag']
# ['mirrored gold bag', 'dotted maroon bag']
# ['drab lavender bag', 'pale turquoise bag', 'faded lime bag', 'bright aqua bag']
# ['mirrored red bag', 'shiny tan bag', 'muted aqua bag', 'pale salmon bag', 'bright violet bag']
# ['clear gray bag', 'bright lavender bag', 'dotted plum bag', 'drab coral bag', 'faded aqua bag']
# ['dull aqua bag', 'wavy coral bag']
# ['muted yellow bag', 'drab olive bag', 'pale lime bag', 'striped crimson bag', 'wavy blue bag']
# ['shiny chartreuse bag', 'bright yellow bag']
# ['posh turquoise bag', 'dotted blue bag', 'pale lime bag', 'mirrored fuchsia bag']
# ['faded maroon bag', 'striped indigo bag', 'light aqua bag', 'dim chartreuse bag', 'vibrant tomato bag']
# ['dotted lavender bag', 'pale crimson bag', 'wavy gray bag', 'plaid plum bag', 'mirrored bronze bag']
# ['striped olive bag', 'dull lime bag']
# ['vibrant aqua bag', 'drab tan bag', 'bright coral bag', 'pale brown bag']
# ['wavy aqua bag', 'dim lime bag', 'dotted bronze bag', 'bright gray bag']
# ['pale green bag', 'shiny purple bag', 'dim plum bag']
# ['vibrant purple bag', 'pale gray bag', 'dull crimson bag']
# ['faded green bag', 'dotted plum bag', 'light white bag']
# ['posh orange bag', 'light blue bag']
# ['drab tomato bag', 'dull salmon bag', 'plaid orange bag', 'posh gray bag']
# ['vibrant beige bag', 'dull fuchsia bag']
# ['wavy orange bag', 'bright tan bag', 'light beige bag', 'vibrant turquoise bag']
# ['light salmon bag', 'dark blue bag', 'bright orange bag']
# ['light blue bag', 'clear chartreuse bag', 'dull olive bag']
# ['dull crimson bag', 'dim gold bag', 'dark tan bag', 'dark lavender bag']
# ['dim teal bag', 'striped gray bag', 'shiny fuchsia bag', 'vibrant chartreuse bag', 'drab plum bag']
# ['striped crimson bag', 'no other bag']
# ['dark brown bag', 'dim plum bag']
# ['dotted tan bag', 'striped fuchsia bag']
# ['bright turquoise bag', 'light orange bag', 'wavy bronze bag', 'light beige bag']
# ['drab salmon bag', 'wavy silver bag']
# ['light brown bag', 'clear gold bag']
# ['plaid aqua bag', 'shiny maroon bag', 'mirrored gray bag']
# ['posh chartreuse bag', 'clear maroon bag', 'wavy black bag', 'vibrant white bag']
# ['wavy gray bag', 'shiny violet bag', 'striped silver bag', 'pale lime bag']
# ['dim crimson bag', 'wavy blue bag', 'dull red bag', 'dotted plum bag']
# ['wavy black bag', 'dim crimson bag', 'dotted chartreuse bag']
# ['faded gray bag', 'plaid white bag', 'mirrored yellow bag']
# ['muted violet bag', 'vibrant blue bag', 'shiny beige bag']
# ['dull white bag', 'dull olive bag', 'clear chartreuse bag', 'dull red bag', 'wavy red bag']
# ['light bronze bag', 'bright gray bag', 'light tomato bag', 'shiny white bag', 'clear silver bag']
# ['plaid violet bag', 'vibrant indigo bag', 'dim turquoise bag']
# ['posh purple bag', 'wavy purple bag']
# ['bright olive bag', 'muted bronze bag', 'mirrored green bag', 'dim plum bag', 'bright silver bag']
# ['vibrant olive bag', 'vibrant beige bag', 'striped gold bag', 'shiny beige bag', 'faded blue bag']
# ['muted fuchsia bag', 'vibrant red bag']
# ['plaid indigo bag', 'dull lime bag', 'faded violet bag']
# ['wavy chartreuse bag', 'dotted yellow bag']
# ['posh magenta bag', 'bright gray bag', 'dotted turquoise bag']
# ['drab teal bag', 'dotted plum bag', 'light white bag', 'dark plum bag', 'dim crimson bag']
# ['dark coral bag', 'wavy chartreuse bag', 'plaid bronze bag', 'muted magenta bag']
# ['posh white bag', 'dotted turquoise bag', 'mirrored lime bag']
# ['mirrored brown bag', 'shiny chartreuse bag', 'light bronze bag', 'bright bronze bag', 'dotted crimson bag']
# ['faded cyan bag', 'dull crimson bag', 'light chartreuse bag', 'light salmon bag']
# ['bright maroon bag', 'dotted yellow bag', 'bright gray bag', 'dim yellow bag', 'light fuchsia bag']
# ['clear silver bag', 'faded green bag', 'posh white bag', 'dark plum bag']
# ['shiny crimson bag', 'dark lavender bag', 'dotted gold bag', 'dark tan bag']
# ['wavy olive bag', 'dotted cyan bag']
# ['wavy coral bag', 'dim gold bag', 'dim silver bag', 'faded green bag', 'muted purple bag']
# ['striped chartreuse bag', 'mirrored plum bag', 'dull tan bag', 'muted gold bag']
# ['bright blue bag', 'mirrored beige bag', 'muted bronze bag', 'dark tan bag', 'dark cyan bag']
# ['vibrant red bag', 'light chartreuse bag', 'faded indigo bag', 'drab teal bag', 'striped indigo bag']
# ['dim cyan bag', 'faded silver bag', 'wavy coral bag']
# ['muted gold bag', 'pale coral bag']
# ['wavy violet bag', 'dotted gray bag', 'clear tan bag', 'plaid brown bag']
# ['light maroon bag', 'faded silver bag']
# ['light cyan bag', 'pale brown bag', 'pale black bag', 'light tomato bag', 'faded violet bag']
# ['pale turquoise bag', 'dull white bag', 'muted tomato bag', 'clear gold bag']
# ['clear plum bag', 'dotted orange bag', 'bright olive bag', 'striped violet bag']
# ['plaid silver bag', 'muted olive bag', 'vibrant bronze bag', 'dull lavender bag', 'dark purple bag']
# ['clear gold bag', 'dotted turquoise bag', 'dark indigo bag']
# ['muted indigo bag', 'mirrored orange bag', 'dull beige bag']
# ['light plum bag', 'drab brown bag', 'wavy cyan bag', 'vibrant lavender bag']
# ['dim maroon bag', 'dull tan bag']
# ['pale lime bag', 'dotted maroon bag', 'faded silver bag', 'shiny tomato bag']
# ['shiny black bag', 'dull crimson bag']
# ['wavy indigo bag', 'light fuchsia bag']
# ['dull lime bag', 'no other bag']
# ['shiny fuchsia bag', 'drab fuchsia bag', 'shiny cyan bag', 'muted black bag', 'dull aqua bag']
# ['muted lavender bag', 'dull fuchsia bag', 'dim chartreuse bag', 'vibrant gold bag', 'shiny beige bag']
# ['bright cyan bag', 'dark gold bag', 'vibrant cyan bag', 'pale coral bag']
# ['posh black bag', 'dull violet bag', 'drab coral bag']
# ['posh olive bag', 'muted magenta bag', 'dark plum bag', 'shiny violet bag']
# ['dull coral bag', 'dark gold bag', 'striped silver bag', 'vibrant lavender bag', 'light red bag']
# ['clear bronze bag', 'striped cyan bag', 'dotted chartreuse bag', 'shiny maroon bag']
# ['bright red bag', 'dark violet bag', 'pale brown bag']
# ['muted silver bag', 'bright blue bag', 'shiny blue bag', 'muted bronze bag', 'bright tan bag']
# ['dotted maroon bag', 'muted white bag', 'dull lime bag', 'dim gold bag', 'faded fuchsia bag']
# ['clear lime bag', 'striped gold bag', 'vibrant purple bag', 'dotted green bag', 'light tomato bag']
# ['shiny tan bag', 'dark lavender bag', 'dull red bag', 'vibrant turquoise bag', 'faded fuchsia bag']
# ['dark teal bag', 'dotted brown bag', 'clear salmon bag', 'wavy coral bag', 'light fuchsia bag']
# ['shiny cyan bag', 'mirrored gold bag', 'mirrored aqua bag', 'posh magenta bag']
# ['pale red bag', 'vibrant turquoise bag']
# ['drab coral bag', 'faded tomato bag', 'plaid aqua bag']
# ['clear white bag', 'dull white bag', 'shiny tan bag', 'mirrored yellow bag', 'wavy chartreuse bag']
# ['clear crimson bag', 'muted white bag', 'vibrant yellow bag']
# ['posh lavender bag', 'mirrored aqua bag', 'faded aqua bag', 'light red bag']
# ['dim violet bag', 'dull orange bag', 'dull turquoise bag', 'dark purple bag']
# ['pale beige bag', 'wavy indigo bag', 'dark plum bag', 'dark purple bag', 'dim turquoise bag']
# ['striped brown bag', 'bright lime bag', 'wavy coral bag']
# ['shiny blue bag', 'wavy coral bag', 'dotted plum bag']
# ['pale black bag', 'clear maroon bag', 'striped crimson bag', 'dark gold bag']
# ['drab plum bag', 'clear gold bag']
# ['posh beige bag', 'faded silver bag', 'dim gold bag', 'shiny gold bag']
# ['clear lavender bag', 'clear white bag']
# ['light lavender bag', 'dotted violet bag', 'dull violet bag', 'dark maroon bag', 'striped violet bag']
# ['plaid brown bag', 'dotted yellow bag']
# ['dotted green bag', 'dull red bag', 'faded green bag', 'muted white bag', 'dim turquoise bag']
# ['muted olive bag', 'vibrant tan bag', 'dotted black bag']
# ['light turquoise bag', 'wavy blue bag', 'dim plum bag', 'dim chartreuse bag']
# ['dim salmon bag', 'mirrored yellow bag']
# ['shiny white bag', 'mirrored violet bag']
# ['drab olive bag', 'striped crimson bag', 'dotted maroon bag']
# ['drab silver bag', 'shiny cyan bag', 'dull teal bag', 'dark lime bag']
# ['vibrant turquoise bag', 'striped crimson bag', 'dark plum bag', 'dark lavender bag', 'dark purple bag']
# ['shiny purple bag', 'posh beige bag', 'dark indigo bag', 'plaid fuchsia bag', 'dotted green bag']
# ['bright brown bag', 'striped lavender bag', 'light gold bag', 'dim maroon bag']
# ['dotted violet bag', 'striped blue bag']
# ['bright crimson bag', 'muted gold bag', 'vibrant turquoise bag', 'wavy green bag', 'dull white bag']
# ['striped tan bag', 'wavy gray bag', 'bright gray bag', 'plaid cyan bag', 'vibrant magenta bag']
# ['dull green bag', 'bright brown bag', 'posh beige bag', 'mirrored crimson bag', 'dark silver bag']
# ['mirrored lime bag', 'muted tomato bag', 'wavy chartreuse bag', 'dotted plum bag']
# ['striped beige bag', 'striped bronze bag', 'shiny yellow bag', 'pale gray bag', 'vibrant tomato bag']
# ['vibrant lime bag', 'striped crimson bag', 'pale silver bag', 'clear purple bag']
# ['pale blue bag', 'bright cyan bag', 'shiny fuchsia bag', 'wavy turquoise bag', 'dotted silver bag']
# ['striped maroon bag', 'muted lime bag']
# ['faded chartreuse bag', 'mirrored white bag']
# ['mirrored crimson bag', 'dotted gold bag', 'shiny red bag', 'wavy red bag']
# ['dull beige bag', 'posh red bag', 'vibrant turquoise bag', 'dark plum bag', 'clear aqua bag']
# ['wavy green bag', 'shiny crimson bag']
# ['striped salmon bag', 'dim plum bag', 'mirrored indigo bag']
# ['faded coral bag', 'muted tomato bag', 'light chartreuse bag']
# ['dark blue bag', 'shiny violet bag']
# ['shiny gold bag', 'dull lime bag', 'pale coral bag', 'wavy silver bag', 'muted black bag']
# ['clear turquoise bag', 'posh magenta bag']
# ['dotted salmon bag', 'mirrored lime bag', 'mirrored salmon bag']
# ['pale gray bag', 'bright blue bag', 'muted tan bag']
# ['shiny teal bag', 'pale indigo bag']
# ['drab beige bag', 'faded indigo bag', 'vibrant bronze bag', 'pale lime bag', 'dark black bag']
# ['vibrant white bag', 'striped violet bag', 'bright blue bag', 'dim gold bag']
# ['posh aqua bag', 'plaid violet bag', 'drab chartreuse bag']
# ['plaid gray bag', 'dotted cyan bag', 'mirrored silver bag']
# ['clear indigo bag', 'bright tan bag', 'dull yellow bag', 'mirrored lavender bag', 'mirrored fuchsia bag']
# ['mirrored turquoise bag', 'faded chartreuse bag', 'drab turquoise bag']
# ['dark chartreuse bag', 'mirrored silver bag', 'vibrant crimson bag', 'shiny green bag', 'pale brown bag']
# ['pale tomato bag', 'light gold bag']
# ['mirrored purple bag', 'light magenta bag', 'shiny yellow bag', 'striped lavender bag']
# ['mirrored blue bag', 'posh magenta bag', 'dark lavender bag', 'striped crimson bag']
# ['dull purple bag', 'mirrored indigo bag', 'wavy bronze bag', 'muted white bag', 'shiny crimson bag']
# ['mirrored teal bag', 'dim teal bag', 'dark lime bag', 'mirrored yellow bag', 'mirrored turquoise bag']
# ['drab gold bag', 'dark maroon bag', 'plaid beige bag']
# ['dotted gold bag', 'striped crimson bag', 'clear red bag']
# ['posh fuchsia bag', 'dim cyan bag', 'vibrant turquoise bag', 'dotted plum bag']
# ['dim lime bag', 'posh indigo bag']
# ['dim tan bag', 'pale indigo bag', 'striped turquoise bag', 'plaid coral bag']
# ['plaid red bag', 'wavy gold bag', 'muted plum bag', 'vibrant plum bag', 'dim brown bag']
# ['light orange bag', 'dotted teal bag', 'dotted yellow bag']
# ['dark green bag', 'dull cyan bag']
# ['posh coral bag', 'shiny green bag', 'dotted red bag', 'drab silver bag']
# ['striped orange bag', 'plaid plum bag']
# ['pale purple bag', 'vibrant coral bag', 'shiny olive bag', 'clear orange bag']
# ['bright fuchsia bag', 'bright yellow bag']
# ['striped red bag', 'bright orange bag', 'mirrored yellow bag', 'dotted coral bag', 'clear aqua bag']
# ['faded plum bag', 'shiny tan bag', 'dull tan bag']
# ['striped gold bag', 'shiny crimson bag']
# ['faded olive bag', 'shiny lavender bag', 'posh fuchsia bag', 'pale gray bag']
# ['pale aqua bag', 'posh beige bag']
# ['dotted plum bag', 'clear red bag']
# ['dotted chartreuse bag', 'light white bag', 'drab turquoise bag']
# ['striped tomato bag', 'dim plum bag', 'striped black bag', 'drab black bag']
# ['shiny lime bag', 'drab coral bag', 'drab green bag', 'muted salmon bag']
# ['dim orange bag', 'striped chartreuse bag']
# ['plaid tan bag', 'light chartreuse bag', 'dotted maroon bag', 'clear silver bag']
# ['dull olive bag', 'muted gold bag', 'dotted gold bag', 'muted white bag', 'shiny violet bag']
# ['dotted beige bag', 'clear tan bag']
# ['dotted silver bag', 'faded crimson bag']
# ['muted black bag', 'clear red bag', 'dotted maroon bag']
# ['clear purple bag', 'dotted plum bag']
# ['striped indigo bag', 'mirrored blue bag', 'striped violet bag', 'striped yellow bag']
# ['faded teal bag', 'light black bag', 'vibrant maroon bag']
# ['drab red bag', 'dark tan bag', 'pale red bag', 'faded salmon bag', 'dotted tomato bag']
# ['muted aqua bag', 'striped purple bag', 'vibrant orange bag', 'bright cyan bag']
# ['mirrored black bag', 'muted yellow bag', 'light fuchsia bag']
# ['dark gold bag', 'dark indigo bag', 'muted magenta bag', 'dull white bag']
# ['dotted lime bag', 'shiny blue bag', 'striped fuchsia bag']
# ['posh brown bag', 'muted beige bag']
# ['muted green bag', 'bright white bag', 'dim gold bag']
# ['vibrant salmon bag', 'pale green bag', 'light maroon bag', 'striped violet bag']
# ['drab white bag', 'drab fuchsia bag', 'dull beige bag', 'pale coral bag', 'shiny tan bag']
# ['light lime bag', 'dotted salmon bag', 'dark fuchsia bag', 'vibrant indigo bag']
# ['shiny tomato bag', 'wavy green bag', 'striped blue bag', 'faded green bag', 'muted tomato bag']
# ['mirrored aqua bag', 'dark gold bag', 'shiny green bag']
# ['plaid cyan bag', 'shiny brown bag', 'pale aqua bag', 'striped turquoise bag', 'plaid yellow bag']
# ['light crimson bag', 'bright silver bag', 'dark lime bag']
# ['dull cyan bag', 'pale gray bag', 'light beige bag', 'striped blue bag']
# ['muted plum bag', 'muted turquoise bag', 'wavy lavender bag', 'striped blue bag', 'striped gray bag']
# ['posh tan bag', 'dark brown bag', 'drab crimson bag']
# ['clear yellow bag', 'striped purple bag', 'faded blue bag']
# ['wavy fuchsia bag', 'light beige bag', 'faded fuchsia bag']
# ['pale gold bag', 'faded green bag', 'clear bronze bag', 'vibrant aqua bag', 'muted cyan bag']
# ['shiny gray bag', 'plaid chartreuse bag']
# ['bright indigo bag', 'drab fuchsia bag']
# ['drab black bag', 'shiny brown bag', 'posh blue bag']
# ['dark crimson bag', 'faded olive bag', 'mirrored green bag']
# ['vibrant silver bag', 'dark black bag', 'drab tan bag']
# ['shiny green bag', 'dark plum bag', 'drab fuchsia bag', 'dim plum bag', 'mirrored gold bag']
# ['plaid crimson bag', 'dim olive bag', 'bright brown bag', 'dull lavender bag']
# ['dark salmon bag', 'light gold bag', 'shiny blue bag']
# ['faded blue bag', 'striped crimson bag', 'muted tomato bag']
# ['wavy magenta bag', 'wavy purple bag', 'bright yellow bag', 'shiny maroon bag', 'wavy orange bag']
# ['striped cyan bag', 'dotted plum bag', 'bright coral bag']
# ['faded crimson bag', 'pale aqua bag', 'light blue bag']
# ['muted gray bag', 'shiny tomato bag']
# ['striped aqua bag', 'dim crimson bag']
# ['wavy salmon bag', 'drab bronze bag', 'light maroon bag']
# ['drab fuchsia bag', 'faded black bag', 'shiny crimson bag', 'shiny tan bag']
# ['clear black bag', 'dark crimson bag', 'pale lavender bag']
# ['dotted orange bag', 'dotted coral bag', 'shiny gold bag', 'wavy coral bag']
# ['plaid tomato bag', 'wavy orange bag']
# ['dark white bag', 'posh cyan bag']
# ['wavy lime bag', 'faded silver bag', 'vibrant gold bag', 'vibrant coral bag']
# ['faded tomato bag', 'striped bronze bag', 'dotted green bag']
# ['mirrored salmon bag', 'faded crimson bag', 'muted gold bag', 'clear aqua bag']
# ['drab maroon bag', 'clear silver bag', 'vibrant cyan bag', 'faded gold bag']
# ['dull violet bag', 'shiny tomato bag']
# ['bright orange bag', 'bright tan bag']
# ['plaid magenta bag', 'light fuchsia bag']
# ['shiny turquoise bag', 'muted bronze bag', 'bright lavender bag', 'dark tan bag']
# ['pale fuchsia bag', 'dull crimson bag', 'wavy red bag', 'dark gold bag']
# ['plaid fuchsia bag', 'dim cyan bag', 'bright coral bag']
# ['dark indigo bag', 'dotted teal bag', 'striped blue bag']
# ['vibrant bronze bag', 'mirrored plum bag', 'faded silver bag']
# ['light tomato bag', 'posh fuchsia bag', 'mirrored magenta bag', 'muted gold bag', 'dim green bag']
# ['shiny silver bag', 'dim yellow bag', 'wavy coral bag']
# ['bright bronze bag', 'plaid coral bag', 'wavy coral bag', 'bright gray bag']
# ['plaid turquoise bag', 'dim lime bag']
# ['plaid teal bag', 'vibrant teal bag', 'dark indigo bag', 'plaid fuchsia bag']
# ['striped purple bag', 'striped chartreuse bag', 'clear chartreuse bag', 'dark cyan bag', 'striped salmon bag']
# ['pale orange bag', 'muted green bag']
# ['light green bag', 'plaid plum bag']
# ['plaid purple bag', 'muted lime bag']
# ['dark cyan bag', 'no other bag']
# ['wavy teal bag', 'dull black bag', 'striped teal bag', 'dotted cyan bag', 'vibrant olive bag']
# ['shiny indigo bag', 'dull lavender bag']
# ['bright beige bag', 'bright bronze bag']
# ['light white bag', 'no other bag']
# ['muted red bag', 'light tan bag', 'clear cyan bag']
# ['light coral bag', 'dull aqua bag', 'bright beige bag', 'wavy maroon bag', 'posh tan bag']
# ['bright violet bag', 'drab beige bag', 'shiny fuchsia bag', 'shiny cyan bag', 'light gray bag']
# ['striped fuchsia bag', 'striped black bag', 'shiny white bag', 'dim plum bag']
# ['vibrant teal bag', 'faded tomato bag', 'dim gray bag']
# ['striped turquoise bag', 'wavy silver bag', 'bright orange bag', 'plaid coral bag', 'clear red bag']
# ['mirrored fuchsia bag', 'dotted green bag', 'plaid cyan bag']
# ['dim green bag', 'posh olive bag', 'dim silver bag']
# ['faded orange bag', 'drab beige bag', 'vibrant salmon bag', 'plaid orange bag']
# ['bright tomato bag', 'dim aqua bag', 'posh beige bag', 'striped purple bag']
# ['faded lime bag', 'bright tan bag']
# ['mirrored indigo bag', 'shiny tan bag', 'faded blue bag']
# ['vibrant orange bag', 'vibrant olive bag', 'bright olive bag', 'wavy violet bag']
# ['plaid beige bag', 'shiny violet bag', 'faded violet bag']
# ['muted purple bag', 'light beige bag', 'bright tan bag']
# ['mirrored orange bag', 'plaid lime bag', 'dotted olive bag']
# ['wavy purple bag', 'dim chartreuse bag']
# ['wavy blue bag', 'striped blue bag', 'posh olive bag']
# ['dull black bag', 'dotted plum bag']
# ['drab bronze bag', 'dim olive bag', 'vibrant gray bag', 'pale green bag', 'dull cyan bag']
# ['pale coral bag', 'dim gold bag', 'vibrant bronze bag']
# ['dull orange bag', 'shiny turquoise bag']
# ['mirrored gray bag', 'mirrored plum bag', 'dim silver bag']
# ['drab cyan bag', 'dark fuchsia bag', 'striped salmon bag', 'plaid beige bag', 'dim olive bag']
# ['dark bronze bag', 'pale salmon bag', 'dull magenta bag', 'clear indigo bag', 'wavy plum bag']
# ['dim tomato bag', 'striped lavender bag']
# ['faded white bag', 'striped lime bag', 'dotted orange bag']
# ['dull teal bag', 'vibrant yellow bag']
# ['clear teal bag', 'wavy gold bag']
# ['muted tan bag', 'faded green bag']
# ['dim gold bag', 'no other bag']
# ['dim turquoise bag', 'mirrored plum bag', 'bright orange bag', 'muted tan bag']
# ['striped silver bag', 'dull lime bag', 'striped blue bag']
# ['striped yellow bag', 'vibrant crimson bag']
# ['striped violet bag', 'clear beige bag', 'dim indigo bag', 'muted lime bag']
# ['posh cyan bag', 'faded blue bag', 'vibrant magenta bag', 'dull lime bag', 'shiny blue bag']
# ['vibrant brown bag', 'shiny violet bag']
# ['pale chartreuse bag', 'wavy teal bag', 'muted maroon bag', 'clear turquoise bag']
# ['vibrant indigo bag', 'drab teal bag', 'bright aqua bag']
# ['bright green bag', 'drab silver bag', 'shiny gold bag']
# ['dim black bag', 'faded violet bag']
# ['muted orange bag', 'dull yellow bag', 'vibrant blue bag', 'plaid tan bag', 'dotted teal bag']
# ['muted crimson bag', 'muted silver bag', 'shiny lavender bag', 'posh beige bag', 'shiny purple bag']
# ['clear tomato bag', 'dotted teal bag', 'vibrant olive bag', 'plaid magenta bag', 'bright chartreuse bag']
# ['vibrant fuchsia bag', 'dim cyan bag', 'light white bag', 'dull orange bag', 'dark gold bag']
# ['muted magenta bag', 'no other bag']
# ['dim brown bag', 'striped red bag', 'posh fuchsia bag', 'mirrored gold bag']
# ['dim plum bag', 'vibrant turquoise bag', 'clear chartreuse bag', 'faded brown bag']
# ['plaid gold bag', 'drab tomato bag']
# ['wavy tomato bag', 'dark gold bag', 'light orange bag', 'muted salmon bag', 'muted olive bag']
# ['pale olive bag', 'plaid cyan bag']
# ['wavy plum bag', 'faded aqua bag', 'dull olive bag', 'bright lavender bag', 'drab chartreuse bag']
# ['posh tomato bag', 'drab blue bag']
# ['dull gray bag', 'dull olive bag', 'mirrored coral bag', 'striped lavender bag']
# ['posh plum bag', 'dull cyan bag', 'dotted orange bag', 'plaid indigo bag', 'light beige bag']
# ['striped plum bag', 'drab white bag', 'mirrored yellow bag', 'dim crimson bag', 'pale salmon bag']
# ['light beige bag', 'dark cyan bag', 'striped crimson bag']
# ['dark maroon bag', 'light tan bag', 'faded green bag', 'striped gold bag', 'bright aqua bag']
# ['faded brown bag', 'dotted gold bag', 'striped turquoise bag', 'bright tan bag', 'clear chartreuse bag']
# ['striped lime bag', 'dim gold bag', 'pale coral bag', 'mirrored plum bag']
# ['light olive bag', 'shiny white bag', 'dotted plum bag', 'clear orange bag', 'posh turquoise bag']
# ['light magenta bag', 'shiny turquoise bag']
# ['dotted turquoise bag', 'posh olive bag']
# ['dark violet bag', 'faded blue bag', 'shiny green bag']
# ['shiny plum bag', 'dotted blue bag', 'clear gold bag']
# ['striped bronze bag', 'dim chartreuse bag', 'shiny violet bag']
# ['vibrant lavender bag', 'faded fuchsia bag', 'shiny blue bag', 'dotted plum bag']
# ['dotted crimson bag', 'dark cyan bag', 'dim chartreuse bag', 'light red bag']
# ['posh blue bag', 'bright silver bag', 'drab beige bag', 'dim salmon bag']
# ['plaid orange bag', 'dark lime bag']
# ['wavy gold bag', 'drab olive bag', 'shiny cyan bag', 'drab brown bag']
# ['muted lime bag', 'dull teal bag']
# ['vibrant magenta bag', 'muted gray bag']
# ['posh silver bag', 'bright lavender bag', 'light gold bag', 'posh beige bag', 'dull crimson bag']
# ['shiny bronze bag', 'pale lavender bag', 'plaid bronze bag', 'mirrored blue bag', 'bright olive bag']
# ['dotted tomato bag', 'drab yellow bag']
# ['posh violet bag', 'muted fuchsia bag', 'dark blue bag', 'shiny indigo bag']
# ['wavy turquoise bag', 'shiny yellow bag']
# ['plaid lavender bag', 'dim lavender bag', 'dotted salmon bag']
# ['striped teal bag', 'mirrored crimson bag', 'mirrored violet bag', 'dark violet bag', 'dotted yellow bag']
# ['faded black bag', 'posh red bag']
# ['faded tan bag', 'mirrored violet bag', 'dark lime bag', 'dim green bag', 'muted green bag']
# ['clear brown bag', 'pale coral bag', 'plaid coral bag', 'pale gray bag']
# ['light violet bag', 'dim plum bag', 'muted violet bag', 'drab teal bag']
# ['dotted gray bag', 'mirrored white bag', 'vibrant lavender bag', 'dark lime bag', 'vibrant coral bag']
# ['faded yellow bag', 'plaid bronze bag', 'dark purple bag', 'shiny crimson bag', 'shiny tan bag']
# ['shiny violet bag', 'dull lime bag', 'muted white bag', 'dark cyan bag']
# ['faded gold bag', 'plaid aqua bag']
# ['bright salmon bag', 'shiny lavender bag', 'plaid red bag']
# ['clear violet bag', 'posh turquoise bag']
# ['light silver bag', 'light salmon bag', 'clear aqua bag', 'mirrored plum bag', 'striped silver bag']
# ['pale cyan bag', 'vibrant orange bag', 'light salmon bag', 'striped cyan bag', 'wavy gray bag']
# ['wavy cyan bag', 'light orange bag', 'bright yellow bag', 'pale fuchsia bag']
# ['clear maroon bag', 'dotted coral bag', 'plaid yellow bag']
# ['striped blue bag', 'light white bag', 'dull lime bag', 'shiny maroon bag']
# ['clear red bag', 'no other bag']
# ['pale tan bag', 'light gold bag', 'dark brown bag', 'wavy black bag', 'drab blue bag']
# ['mirrored magenta bag', 'dotted plum bag', 'posh beige bag']
# ['dull maroon bag', 'mirrored fuchsia bag']
# ['dim silver bag', 'striped crimson bag', 'light beige bag']
# ['plaid olive bag', 'shiny white bag', 'bright lavender bag']
# ['shiny magenta bag', 'dotted gray bag', 'shiny blue bag', 'faded silver bag', 'dark tomato bag']
# ['mirrored green bag', 'dim cyan bag', 'bright tan bag']
# ['faded silver bag', 'dark plum bag', 'dotted plum bag', 'dark cyan bag', 'dull red bag']
# ['vibrant cyan bag', 'vibrant lavender bag']
# ['shiny brown bag', 'striped blue bag', 'light beige bag', 'muted tan bag', 'bright orange bag']
# ['wavy maroon bag', 'vibrant white bag', 'pale red bag', 'striped yellow bag', 'plaid bronze bag']
# ['shiny aqua bag', 'dotted salmon bag', 'bright maroon bag', 'wavy red bag']
# ['clear cyan bag', 'striped red bag', 'plaid coral bag', 'dark fuchsia bag']
# ['dotted red bag', 'dim orange bag', 'striped tan bag']
# ['vibrant green bag', 'dark plum bag']
# ['striped black bag', 'dull white bag']
# ['dotted indigo bag', 'vibrant orange bag', 'vibrant lavender bag', 'shiny bronze bag']
# ['dark tan bag', 'muted tan bag']
# ['dotted yellow bag', 'dark cyan bag', 'shiny maroon bag']
# ['dull chartreuse bag', 'vibrant red bag', 'dim salmon bag', 'drab salmon bag']
# ['shiny beige bag', 'dotted yellow bag', 'muted tomato bag', 'wavy red bag']
# ['faded indigo bag', 'faded green bag']
# ['light chartreuse bag', 'mirrored violet bag', 'striped lavender bag']
# ['dark red bag', 'dark green bag', 'clear beige bag', 'wavy tan bag', 'striped cyan bag']
# ['muted blue bag', 'dark beige bag', 'bright lavender bag', 'dull teal bag']
# ['mirrored olive bag', 'dark lavender bag', 'clear blue bag']
# ['pale yellow bag', 'dark chartreuse bag', 'posh silver bag', 'dim crimson bag', 'wavy gold bag']
# ['dull brown bag', 'light aqua bag', 'pale aqua bag', 'faded red bag', 'wavy white bag']
# ['clear chartreuse bag', 'wavy coral bag']
# ['bright white bag', 'light fuchsia bag', 'drab turquoise bag', 'striped lime bag']
# ['light gray bag', 'mirrored violet bag', 'dotted maroon bag', 'pale lime bag']
# ['mirrored cyan bag', 'mirrored salmon bag', 'drab olive bag']
# ['dark orange bag', 'vibrant lavender bag']
# ['drab chartreuse bag', 'wavy orange bag']
# ['muted white bag', 'no other bag']
# ['dull red bag', 'faded fuchsia bag', 'dark purple bag', 'clear red bag']
# ['shiny red bag', 'bright gray bag', 'drab blue bag', 'bright aqua bag']
# ['vibrant gold bag', 'shiny tan bag', 'mirrored gold bag']
# ['wavy red bag', 'dark plum bag', 'striped blue bag', 'light white bag', 'wavy silver bag']
# ['mirrored coral bag', 'dark indigo bag']
# ['mirrored beige bag', 'muted white bag']
# ['faded bronze bag', 'bright aqua bag', 'dotted chartreuse bag', 'faded tomato bag']
# ['bright plum bag', 'drab chartreuse bag']
# ['shiny coral bag', 'dark yellow bag', 'dark blue bag', 'dotted green bag']
# ['mirrored yellow bag', 'dotted plum bag']
# ['faded fuchsia bag', 'no other bag']
# ['bright magenta bag', 'muted orange bag', 'striped red bag', 'light bronze bag']
# ['drab aqua bag', 'dotted indigo bag', 'dim gray bag']
# ['faded violet bag', 'shiny gold bag']
# ['dull lavender bag', 'drab chartreuse bag', 'shiny plum bag', 'vibrant tan bag', 'dark tomato bag']
# ['shiny lavender bag', 'light fuchsia bag']
# ['dotted brown bag', 'shiny brown bag', 'light fuchsia bag', 'plaid cyan bag']
# ['dark olive bag', 'wavy red bag', 'striped lavender bag', 'vibrant lavender bag', 'shiny gold bag']
# ['dotted black bag', 'dark lime bag']
# ['faded aqua bag', 'dim turquoise bag', 'muted green bag', 'clear aqua bag']
# ['plaid yellow bag', 'striped turquoise bag', 'striped lime bag']
# ['pale bronze bag', 'muted tan bag', 'dotted fuchsia bag']
# ['muted coral bag', 'striped bronze bag', 'dark violet bag']
# ['dim indigo bag', 'shiny red bag']
# ['drab gray bag', 'posh white bag', 'plaid indigo bag']
# ['pale silver bag', 'faded coral bag', 'shiny lavender bag', 'wavy lime bag']
# ['wavy silver bag', 'vibrant bronze bag']
# ['wavy crimson bag', 'mirrored orange bag']
# ['dotted aqua bag', 'drab plum bag', 'faded indigo bag', 'dark violet bag', 'pale gray bag']
# ['mirrored violet bag', 'mirrored white bag']
# ['dotted white bag', 'muted plum bag', 'bright bronze bag', 'dark salmon bag']
# ['bright coral bag', 'mirrored gray bag']
# ['dim aqua bag', 'mirrored plum bag', 'plaid olive bag', 'light gold bag']
# ['drab crimson bag', 'faded purple bag']
# ['pale crimson bag', 'dotted orange bag', 'faded silver bag']
# ['mirrored tan bag', 'posh gray bag', 'dark silver bag', 'dim tan bag']
# ['clear olive bag', 'dim yellow bag', 'bright blue bag', 'bright tomato bag']
# ['dim blue bag', 'drab black bag', 'light blue bag', 'light orange bag', 'bright white bag']
# ['mirrored chartreuse bag', 'drab beige bag', 'pale indigo bag']
# ['dark turquoise bag', 'vibrant black bag', 'light turquoise bag', 'pale aqua bag']
# ['posh yellow bag', 'dim teal bag', 'dark black bag']
# ['clear aqua bag', 'drab teal bag', 'light gold bag', 'dim crimson bag']
# ['dotted purple bag', 'striped salmon bag']
# ['light indigo bag', 'faded red bag', 'shiny crimson bag', 'wavy green bag', 'striped coral bag']
# ['vibrant yellow bag', 'dotted cyan bag', 'posh silver bag']
# ['faded lavender bag', 'dull cyan bag']
# ['dull magenta bag', 'dotted green bag']
# ['posh indigo bag', 'dull lime bag', 'striped lavender bag', 'faded silver bag']
# ['light aqua bag', 'posh maroon bag', 'dotted black bag', 'muted tomato bag', 'mirrored magenta bag']
# ['mirrored maroon bag', 'light aqua bag']
# ['dim red bag', 'muted green bag', 'vibrant tan bag']
# ['wavy yellow bag', 'dotted cyan bag']
# ['bright aqua bag', 'dotted maroon bag', 'muted white bag', 'striped turquoise bag']
# ['clear fuchsia bag', 'mirrored fuchsia bag', 'bright white bag', 'mirrored white bag', 'bright coral bag']
# ['dotted olive bag', 'pale aqua bag', 'light gold bag', 'dim yellow bag']
# ['light black bag', 'clear tan bag', 'wavy lime bag', 'dim fuchsia bag', 'pale indigo bag']
# ['dark purple bag', 'dark cyan bag']
# ['dim purple bag', 'wavy crimson bag', 'dim chartreuse bag', 'shiny yellow bag', 'light black bag']
# ['plaid salmon bag', 'faded lime bag']
# ['dotted cyan bag', 'shiny tomato bag', 'mirrored plum bag']
# ['posh maroon bag', 'light bronze bag', 'muted tan bag', 'vibrant plum bag']
# ['dim fuchsia bag', 'dim plum bag', 'dark gray bag']
# ['bright tan bag', 'shiny maroon bag', 'light beige bag', 'faded fuchsia bag']
# ['plaid green bag', 'wavy cyan bag', 'dark chartreuse bag', 'dark blue bag']
# ['plaid black bag', 'dull olive bag', 'mirrored white bag', 'plaid white bag']
# ['clear beige bag', 'dull tan bag']
# ['mirrored tomato bag', 'drab tomato bag', 'plaid bronze bag']
# ['dim yellow bag', 'dark indigo bag', 'bright silver bag', 'muted purple bag']
# ['clear tan bag', 'light gold bag', 'bright lavender bag', 'mirrored fuchsia bag']
# ['dim lavender bag', 'vibrant aqua bag']
# ['striped white bag', 'posh tomato bag', 'dark gold bag', 'clear olive bag', 'dotted bronze bag']
# ['wavy bronze bag', 'plaid lime bag', 'plaid yellow bag', 'bright white bag']
# ['shiny orange bag', 'drab chartreuse bag', 'shiny gold bag']
# ['dim coral bag', 'faded silver bag']
# ['bright gold bag', 'dim aqua bag', 'drab bronze bag']
# ['vibrant black bag', 'dotted green bag', 'light brown bag']
# ['bright teal bag', 'light gold bag', 'bright aqua bag']
# ['drab brown bag', 'wavy blue bag', 'wavy orange bag']
# ['dull yellow bag', 'striped green bag', 'bright lime bag', 'faded tan bag', 'dotted green bag']
# ['vibrant maroon bag', 'mirrored fuchsia bag']
# ['vibrant gray bag', 'faded turquoise bag', 'pale black bag', 'drab aqua bag']
# ['pale white bag', 'shiny beige bag']
# ['dim beige bag', 'pale fuchsia bag', 'muted lime bag', 'dotted plum bag']
# ['drab blue bag', 'dim crimson bag', 'shiny beige bag', 'bright silver bag']
# ['dark black bag', 'light beige bag', 'muted gold bag']
# ['plaid bronze bag', 'wavy indigo bag']
# ['posh salmon bag', 'dark salmon bag', 'posh purple bag', 'dim yellow bag']
# ['mirrored lavender bag', 'wavy chartreuse bag', 'plaid bronze bag']
# ['muted brown bag', 'drab magenta bag', 'vibrant plum bag', 'clear purple bag', 'dark blue bag']
# ['wavy white bag', 'striped red bag']
# ['dark gray bag', 'bright blue bag', 'light brown bag']
# ['mirrored silver bag', 'dotted chartreuse bag', 'dotted fuchsia bag', 'mirrored lavender bag', 'mirrored white bag']
# ['wavy brown bag', 'posh teal bag', 'drab white bag', 'shiny chartreuse bag', 'light maroon bag']
# ['posh gray bag', 'striped turquoise bag', 'muted crimson bag', 'clear yellow bag', 'striped crimson bag']
# ['dull tomato bag', 'drab purple bag', 'faded yellow bag']
# ['dotted blue bag', 'dull cyan bag', 'dim plum bag']
# ['vibrant tomato bag', 'plaid coral bag', 'pale fuchsia bag']
# ['wavy beige bag', 'dull magenta bag', 'dotted beige bag', 'bright white bag', 'striped fuchsia bag']
# ['plaid lime bag', 'light blue bag', 'drab brown bag', 'drab teal bag']
# ['dim white bag', 'wavy coral bag', 'vibrant bronze bag', 'dark cyan bag', 'dark plum bag']
# ['bright yellow bag', 'pale aqua bag', 'dim turquoise bag', 'faded brown bag']
# ['plaid maroon bag', 'dark teal bag', 'vibrant white bag', 'striped coral bag', 'shiny white bag']
# ['pale lavender bag', 'shiny violet bag']
# ['drab magenta bag', 'bright gray bag']
# ['clear salmon bag', 'wavy purple bag', 'bright olive bag', 'clear yellow bag']
# ['dark yellow bag', 'bright bronze bag', 'striped plum bag']
# ['posh bronze bag', 'shiny maroon bag', 'drab olive bag', 'mirrored green bag', 'light silver bag']
# ['drab green bag', 'dim orange bag', 'vibrant chartreuse bag']
# ['light fuchsia bag', 'wavy silver bag', 'muted white bag', 'muted black bag', 'faded green bag']
# ['dark plum bag', 'bright tan bag', 'dull lime bag', 'faded fuchsia bag', 'shiny maroon bag']
# ['light teal bag', 'light lavender bag']
# ['vibrant tan bag', 'vibrant bronze bag']
# ['muted teal bag', 'wavy green bag', 'plaid turquoise bag']
# ['bright chartreuse bag', 'muted gold bag', 'posh olive bag', 'vibrant tan bag', 'faded salmon bag']
# ['dotted fuchsia bag', 'pale lime bag']
# ['pale teal bag', 'plaid silver bag', 'shiny turquoise bag', 'dim coral bag', 'vibrant bronze bag']
# ['drab orange bag', 'shiny silver bag', 'vibrant indigo bag', 'mirrored lavender bag', 'dark yellow bag']
# ['clear green bag', 'vibrant beige bag', 'bright crimson bag', 'muted gray bag']
# ['shiny yellow bag', 'light fuchsia bag', 'mirrored plum bag']
# ['plaid blue bag', 'mirrored blue bag', 'plaid olive bag']
# ['mirrored plum bag', 'dull red bag', 'muted magenta bag']
# ['dim bronze bag', 'vibrant olive bag']
# ['posh green bag', 'mirrored blue bag', 'vibrant yellow bag', 'bright yellow bag', 'wavy fuchsia bag']
# ['clear blue bag', 'mirrored yellow bag']
# ['dotted teal bag', 'shiny brown bag', 'faded silver bag', 'plaid coral bag']
# ['muted cyan bag', 'clear aqua bag']
# ['dark fuchsia bag', 'shiny blue bag', 'dull fuchsia bag', 'dull lime bag', 'drab salmon bag']
# ['dark silver bag', 'dim salmon bag']
# ['muted beige bag', 'shiny lavender bag', 'striped chartreuse bag']
# ['dull indigo bag', 'bright beige bag', 'dark gold bag', 'mirrored magenta bag']
# ['bright silver bag', 'faded violet bag', 'dim cyan bag', 'faded indigo bag', 'clear chartreuse bag']
# ['dim olive bag', 'mirrored plum bag', 'clear indigo bag', 'striped crimson bag']
# ['pale magenta bag', 'vibrant black bag', 'muted salmon bag', 'dotted fuchsia bag']
# ['faded turquoise bag', 'light lavender bag', 'clear lavender bag', 'dull coral bag']
# ['posh gold bag', 'clear blue bag']
# ['muted maroon bag', 'dark fuchsia bag', 'muted red bag', 'dim salmon bag']
# ['muted tomato bag', 'striped blue bag', 'dark plum bag', 'faded green bag', 'bright tan bag']
# ['dark lime bag', 'posh white bag', 'dull crimson bag', 'dark cyan bag', 'mirrored plum bag']
# ['posh lime bag', 'wavy violet bag', 'dotted teal bag', 'shiny cyan bag']
# ['light tan bag', 'striped turquoise bag', 'dim white bag', 'shiny violet bag']
# ['dull bronze bag', 'drab teal bag', 'light red bag', 'muted indigo bag']
# ['plaid coral bag', 'dark purple bag', 'striped crimson bag', 'light beige bag']
# ['wavy lavender bag', 'muted white bag']
# ['drab indigo bag', 'dotted green bag', 'striped silver bag']
# ['dull silver bag', 'dark yellow bag', 'light beige bag', 'striped indigo bag', 'wavy violet bag']
# ['dark aqua bag', 'drab violet bag']
# ['muted bronze bag', 'clear chartreuse bag', 'drab turquoise bag', 'pale coral bag']
# ['striped coral bag', 'shiny red bag', 'dark purple bag']
# ['faded beige bag', 'bright fuchsia bag', 'mirrored turquoise bag']
# ['dull plum bag', 'dull aqua bag']
# ['drab lime bag', 'clear aqua bag', 'shiny cyan bag']
# ['pale plum bag', 'shiny silver bag', 'dull coral bag']
# ['pale violet bag', 'wavy purple bag', 'light plum bag', 'striped silver bag', 'drab teal bag']
# ['clear magenta bag', 'dark plum bag', 'striped tan bag', 'posh plum bag', 'dark turquoise bag']
# ['vibrant plum bag', 'dotted teal bag', 'vibrant gold bag']
# ['bright gray bag', 'muted white bag', 'striped crimson bag', 'mirrored gray bag', 'wavy silver bag']
# ['clear coral bag', 'vibrant magenta bag', 'dim orange bag', 'dark black bag']
# ['vibrant chartreuse bag', 'dark lime bag', 'mirrored turquoise bag', 'vibrant indigo bag', 'dull gray bag']
# ['faded purple bag', 'mirrored indigo bag', 'dark indigo bag', 'pale fuchsia bag', 'muted olive bag']
# ['drab violet bag', 'muted black bag', 'clear maroon bag', 'clear gold bag']
# ['dim magenta bag', 'wavy tan bag']
# ['clear orange bag', 'shiny tomato bag', 'faded fuchsia bag']
# ['mirrored white bag', 'dim plum bag', 'mirrored magenta bag']
# ['plaid white bag', 'pale tomato bag', 'posh magenta bag', 'vibrant maroon bag', 'shiny fuchsia bag']
# ['shiny olive bag', 'striped salmon bag', 'mirrored gray bag', 'plaid beige bag']
# ['plaid plum bag', 'bright bronze bag']
# ['dull salmon bag', 'bright white bag', 'muted cyan bag']
# ['pale maroon bag', 'muted tan bag', 'bright gray bag']
# ['faded salmon bag', 'bright silver bag']
# ['striped magenta bag', 'dark plum bag', 'faded bronze bag', 'striped brown bag']
# ['vibrant crimson bag', 'muted lime bag', 'plaid indigo bag']
# ['wavy tan bag', 'shiny yellow bag', 'clear beige bag', 'dotted gold bag']
# ['posh teal bag', 'striped gold bag', 'drab salmon bag', 'shiny plum bag', 'pale gray bag']
# ['dotted coral bag', 'wavy chartreuse bag', 'wavy blue bag']
# ['light purple bag', 'mirrored lime bag']
# ['bright lavender bag', 'faded brown bag']
# ['muted turquoise bag', 'shiny maroon bag', 'light purple bag', 'striped tan bag', 'plaid cyan bag']
# ['posh red bag', 'striped lavender bag', 'dark black bag', 'dark purple bag', 'drab olive bag']
# ['bright black bag', 'dark brown bag', 'clear olive bag', 'plaid olive bag']
# ['mirrored bronze bag', 'wavy turquoise bag']
# ['vibrant violet bag', 'plaid indigo bag', 'faded orange bag']
# ['drab tan bag', 'clear crimson bag', 'mirrored turquoise bag', 'muted magenta bag']
# ['dim gray bag', 'striped black bag', 'muted silver bag', 'dotted blue bag', 'posh gray bag']
# ['dull tan bag', 'clear maroon bag', 'posh beige bag', 'striped crimson bag', 'dim gold bag']
# ['vibrant blue bag', 'bright beige bag', 'bright bronze bag', 'plaid salmon bag']
# ['posh crimson bag', 'mirrored purple bag', 'striped silver bag', 'bright magenta bag', 'bright blue bag']
# ['dotted bronze bag', 'wavy crimson bag', 'muted purple bag', 'light gold bag']
# ['pale brown bag', 'drab coral bag', 'mirrored lavender bag', 'dark tomato bag', 'plaid indigo bag']
# ['shiny maroon bag', 'light beige bag', 'light white bag']
# ['dark tomato bag', 'shiny gold bag', 'clear aqua bag', 'dotted gold bag']
# ['dark beige bag', 'bright gray bag', 'light beige bag', 'dull lime bag']
# ['light red bag', 'mirrored magenta bag', 'mirrored lime bag', 'dotted teal bag']
# ['faded magenta bag', 'dim maroon bag', 'mirrored gray bag', 'dotted beige bag']
# ['drab turquoise bag', 'no other bag']
# ['shiny salmon bag', 'shiny tan bag', 'posh magenta bag', 'clear turquoise bag']
# ['dark magenta bag', 'light fuchsia bag', 'muted yellow bag', 'dotted olive bag', 'dark crimson bag']
# ['light gold bag', 'clear red bag']
# ['faded red bag', 'clear beige bag', 'dim silver bag', 'posh gray bag']
# ['pale salmon bag', 'mirrored white bag']
# ['striped lavender bag', 'striped blue bag']
# ['dull fuchsia bag', 'bright orange bag']
# ['dull turquoise bag', 'vibrant tomato bag', 'clear tan bag', 'bright teal bag', 'drab maroon bag']
# ['dotted magenta bag', 'drab gold bag', 'muted beige bag']
# ['pale indigo bag', 'plaid brown bag', 'plaid cyan bag', 'mirrored black bag', 'drab magenta bag']
# ['drab yellow bag', 'dark turquoise bag', 'dotted beige bag', 'clear red bag', 'muted lavender bag']
# ['striped gray bag', 'bright orange bag', 'muted white bag', 'clear chartreuse bag']
# ['dark lavender bag', 'dim gold bag', 'pale coral bag']
# ['dull gold bag', 'dull beige bag']
# ['muted chartreuse bag', 'muted bronze bag', 'faded black bag', 'bright tan bag']
# ['plaid chartreuse bag', 'dim indigo bag', 'mirrored gold bag', 'dim lime bag']
# ['muted salmon bag', 'faded brown bag', 'dotted black bag', 'muted black bag']
# ['bright purple bag', 'shiny red bag', 'vibrant cyan bag', 'plaid cyan bag', 'bright silver bag']
# ['dim chartreuse bag', 'faded indigo bag']
# ['drab purple bag', 'muted cyan bag', 'wavy lavender bag', 'dotted blue bag']

# %%
re.findall(pattern, inputs[0])[0].strip(' bag')
# Out:
# 'striped green'

# %%
pattern = '(\w*\s\w*\sbag)|(\d\s\w*\s\w*\sbag)'

# %%
def extract_bag_color(x):
    pattern = '(\w*\s\w*\sbag)'
    result = re.findall(pattern, x)
    if result:
        result = [x.strip('bag').strip(' ') for x in result]
        key = result[0]
        value = result[1:]
    return key, value

# %%
print(extract_bag_color(inputs[593]))
# Out:
# ('drab purple', ['muted cyan', 'wavy lavender', 'dotted blue'])

# %%
keys = []
values = []
for item in inputs:
    key, value = extract_bag_color(item)
    keys.append(key)
    values.append(value)

dict_color = {key:value for key, value in zip(keys, values)}

# %%
len(dict_color)
# Out:
# 594

# %%
count_all = 0
control_recursive = 0
color_ = set()

# %%
def count_color(values):
    global count_all, control_recursive, color_
    while control_recursive <= 20:
        color_values = set()
        for key in dict_color.keys():
            for value in values:
                if value in dict_color[key]:
                    color_values.add(key)
                    color_.add(key)
        count_all += len(color_values)
        new_keys = color_values
        control_recursive += 1
        count_color(new_keys)

# %%
values = ['shiny gold']
count_color(values)

# %%
len(color_)
# Out:
# 268

# %%
dict_color['shiny gold']
# Out:
# ['dull lime', 'pale coral', 'wavy silver', 'muted black']

# %%
def extract_bag_color2(x):
    ''' This function is to find patterns in an input then arrange them inside a dictionary'''
    pattern = '(\w*\s\w*\sbag)'
    result = re.findall(pattern, x)
    if result:
        result = [x.replace(' bag','') for x in result]
        key = result[0]
        values = result[1:]
    numbers = []
    for value in values:
        
        pattern2 = '\d+\s' + value
        result = re.search(pattern2, x)
        if result:
            number = int(result.group().partition(' ')[0])
            numbers.append(number)
        else:
            numbers = 1
            break   
    if values == ['no other']:
         dict_bags = {key: numbers}
    else:
        dict_bags = {key:{value:number for value, number in zip(values, numbers)}}
        
    return dict_bags

# %%
big_dict = {}
for i in inputs:
    big_dict.update(extract_bag_color2(i))

# %%
pprint(big_dict)
# Out:
# {'bright aqua': {'dotted maroon': 1, 'muted white': 1, 'striped turquoise': 3},
#  'bright beige': {'bright bronze': 1},
#  'bright black': {'clear olive': 4, 'dark brown': 3, 'plaid olive': 4},
#  'bright blue': {'dark cyan': 5,
#                  'dark tan': 1,
#                  'mirrored beige': 5,
#                  'muted bronze': 4},
#  'bright bronze': {'bright gray': 2, 'plaid coral': 3, 'wavy coral': 2},
#  'bright brown': {'dim maroon': 1, 'light gold': 5, 'striped lavender': 1},
#  'bright chartreuse': {'faded salmon': 2,
#                        'muted gold': 2,
#                        'posh olive': 5,
#                        'vibrant tan': 1},
#  'bright coral': {'mirrored gray': 5},
#  'bright crimson': {'dull white': 5,
#                     'muted gold': 2,
#                     'vibrant turquoise': 3,
#                     'wavy green': 3},
#  'bright cyan': {'dark gold': 5, 'pale coral': 1, 'vibrant cyan': 2},
#  'bright fuchsia': {'bright yellow': 3},
#  'bright gold': {'dim aqua': 5, 'drab bronze': 2},
#  'bright gray': {'mirrored gray': 3,
#                  'muted white': 3,
#                  'striped crimson': 2,
#                  'wavy silver': 4},
#  'bright green': {'drab silver': 4, 'shiny gold': 5},
#  'bright indigo': {'drab fuchsia': 3},
#  'bright lavender': {'faded brown': 5},
#  'bright lime': {'dull red': 3, 'striped crimson': 2},
#  'bright magenta': {'light bronze': 5, 'muted orange': 4, 'striped red': 3},
#  'bright maroon': {'bright gray': 1,
#                    'dim yellow': 2,
#                    'dotted yellow': 3,
#                    'light fuchsia': 5},
#  'bright olive': {'bright silver': 5,
#                   'dim plum': 2,
#                   'mirrored green': 4,
#                   'muted bronze': 4},
#  'bright orange': {'bright tan': 4},
#  'bright plum': {'drab chartreuse': 3},
#  'bright purple': {'bright silver': 5,
#                    'plaid cyan': 4,
#                    'shiny red': 5,
#                    'vibrant cyan': 5},
#  'bright red': {'dark violet': 2, 'pale brown': 4},
#  'bright salmon': {'plaid red': 5, 'shiny lavender': 2},
#  'bright silver': {'clear chartreuse': 1,
#                    'dim cyan': 4,
#                    'faded indigo': 5,
#                    'faded violet': 3},
#  'bright tan': {'faded fuchsia': 2, 'light beige': 1, 'shiny maroon': 1},
#  'bright teal': {'bright aqua': 2, 'light gold': 1},
#  'bright tomato': {'dim aqua': 4, 'posh beige': 2, 'striped purple': 4},
#  'bright turquoise': {'light beige': 2, 'light orange': 3, 'wavy bronze': 2},
#  'bright violet': {'drab beige': 2,
#                    'light gray': 5,
#                    'shiny cyan': 2,
#                    'shiny fuchsia': 3},
#  'bright white': {'drab turquoise': 5, 'light fuchsia': 4, 'striped lime': 5},
#  'bright yellow': {'dim turquoise': 2, 'faded brown': 4, 'pale aqua': 4},
#  'clear aqua': {'dim crimson': 4, 'drab teal': 2, 'light gold': 5},
#  'clear beige': {'dull tan': 1},
#  'clear black': {'dark crimson': 4, 'pale lavender': 5},
#  'clear blue': {'mirrored yellow': 5},
#  'clear bronze': {'dotted chartreuse': 4, 'shiny maroon': 4, 'striped cyan': 4},
#  'clear brown': {'pale coral': 3, 'pale gray': 4, 'plaid coral': 1},
#  'clear chartreuse': {'wavy coral': 2},
#  'clear coral': {'dark black': 3, 'dim orange': 2, 'vibrant magenta': 2},
#  'clear crimson': {'muted white': 5, 'vibrant yellow': 1},
#  'clear cyan': {'dark fuchsia': 2, 'plaid coral': 5, 'striped red': 2},
#  'clear fuchsia': {'bright coral': 1,
#                    'bright white': 4,
#                    'mirrored fuchsia': 2,
#                    'mirrored white': 3},
#  'clear gold': {'dark indigo': 3, 'dotted turquoise': 1},
#  'clear gray': {'bright lavender': 4,
#                 'dotted plum': 2,
#                 'drab coral': 1,
#                 'faded aqua': 3},
#  'clear green': {'bright crimson': 1, 'muted gray': 5, 'vibrant beige': 4},
#  'clear indigo': {'bright tan': 1,
#                   'dull yellow': 2,
#                   'mirrored fuchsia': 2,
#                   'mirrored lavender': 5},
#  'clear lavender': {'clear white': 1},
#  'clear lime': {'dotted green': 5,
#                 'light tomato': 2,
#                 'striped gold': 4,
#                 'vibrant purple': 2},
#  'clear magenta': {'dark plum': 2,
#                    'dark turquoise': 4,
#                    'posh plum': 4,
#                    'striped tan': 2},
#  'clear maroon': {'dotted coral': 1, 'plaid yellow': 4},
#  'clear olive': {'bright blue': 1, 'bright tomato': 3, 'dim yellow': 1},
#  'clear orange': {'faded fuchsia': 1, 'shiny tomato': 5},
#  'clear plum': {'bright olive': 1, 'dotted orange': 2, 'striped violet': 3},
#  'clear purple': {'dotted plum': 5},
#  'clear red': 1,
#  'clear salmon': {'bright olive': 1, 'clear yellow': 1, 'wavy purple': 4},
#  'clear silver': {'dark plum': 4, 'faded green': 4, 'posh white': 4},
#  'clear tan': {'bright lavender': 3, 'light gold': 4, 'mirrored fuchsia': 2},
#  'clear teal': {'wavy gold': 4},
#  'clear tomato': {'bright chartreuse': 4,
#                   'dotted teal': 4,
#                   'plaid magenta': 5,
#                   'vibrant olive': 2},
#  'clear turquoise': {'posh magenta': 1},
#  'clear violet': {'posh turquoise': 4},
#  'clear white': {'dull white': 1,
#                  'mirrored yellow': 1,
#                  'shiny tan': 5,
#                  'wavy chartreuse': 1},
#  'clear yellow': {'faded blue': 4, 'striped purple': 3},
#  'dark aqua': {'drab violet': 1},
#  'dark beige': {'bright gray': 2, 'dull lime': 1, 'light beige': 3},
#  'dark black': {'light beige': 5, 'muted gold': 5},
#  'dark blue': {'shiny violet': 2},
#  'dark bronze': {'clear indigo': 5,
#                  'dull magenta': 5,
#                  'pale salmon': 2,
#                  'wavy plum': 3},
#  'dark brown': {'dim plum': 1},
#  'dark chartreuse': {'mirrored silver': 2,
#                      'pale brown': 1,
#                      'shiny green': 4,
#                      'vibrant crimson': 3},
#  'dark coral': {'muted magenta': 1, 'plaid bronze': 3, 'wavy chartreuse': 3},
#  'dark crimson': {'faded olive': 5, 'mirrored green': 1},
#  'dark cyan': 1,
#  'dark fuchsia': {'drab salmon': 5,
#                   'dull fuchsia': 1,
#                   'dull lime': 2,
#                   'shiny blue': 1},
#  'dark gold': {'dark indigo': 2, 'dull white': 3, 'muted magenta': 3},
#  'dark gray': {'bright blue': 5, 'light brown': 2},
#  'dark green': {'dull cyan': 1},
#  'dark indigo': {'dotted teal': 3, 'striped blue': 3},
#  'dark lavender': {'dim gold': 5, 'pale coral': 2},
#  'dark lime': {'dark cyan': 2,
#                'dull crimson': 4,
#                'mirrored plum': 4,
#                'posh white': 2},
#  'dark magenta': {'dark crimson': 4,
#                   'dotted olive': 5,
#                   'light fuchsia': 1,
#                   'muted yellow': 3},
#  'dark maroon': {'bright aqua': 4,
#                  'faded green': 5,
#                  'light tan': 5,
#                  'striped gold': 3},
#  'dark olive': {'shiny gold': 2,
#                 'striped lavender': 5,
#                 'vibrant lavender': 4,
#                 'wavy red': 2},
#  'dark orange': {'vibrant lavender': 3},
#  'dark plum': {'bright tan': 4,
#                'dull lime': 4,
#                'faded fuchsia': 2,
#                'shiny maroon': 4},
#  'dark purple': {'dark cyan': 5},
#  'dark red': {'clear beige': 3,
#               'dark green': 5,
#               'striped cyan': 4,
#               'wavy tan': 5},
#  'dark salmon': {'light gold': 2, 'shiny blue': 4},
#  'dark silver': {'dim salmon': 2},
#  'dark tan': {'muted tan': 1},
#  'dark teal': {'clear salmon': 5,
#                'dotted brown': 2,
#                'light fuchsia': 3,
#                'wavy coral': 5},
#  'dark tomato': {'clear aqua': 5, 'dotted gold': 2, 'shiny gold': 5},
#  'dark turquoise': {'light turquoise': 1, 'pale aqua': 5, 'vibrant black': 1},
#  'dark violet': {'faded blue': 1, 'shiny green': 1},
#  'dark white': {'posh cyan': 3},
#  'dark yellow': {'bright bronze': 1, 'striped plum': 3},
#  'dim aqua': {'light gold': 1, 'mirrored plum': 3, 'plaid olive': 3},
#  'dim beige': {'dotted plum': 3, 'muted lime': 1, 'pale fuchsia': 1},
#  'dim black': {'faded violet': 1},
#  'dim blue': {'bright white': 5,
#               'drab black': 3,
#               'light blue': 1,
#               'light orange': 5},
#  'dim bronze': {'vibrant olive': 3},
#  'dim brown': {'mirrored gold': 3, 'posh fuchsia': 4, 'striped red': 1},
#  'dim chartreuse': {'faded indigo': 1},
#  'dim coral': {'faded silver': 2},
#  'dim crimson': {'dotted plum': 1, 'dull red': 1, 'wavy blue': 1},
#  'dim cyan': {'faded silver': 5, 'wavy coral': 3},
#  'dim fuchsia': {'dark gray': 5, 'dim plum': 3},
#  'dim gold': 1,
#  'dim gray': {'dotted blue': 1,
#               'muted silver': 5,
#               'posh gray': 3,
#               'striped black': 5},
#  'dim green': {'dim silver': 1, 'posh olive': 1},
#  'dim indigo': {'shiny red': 1},
#  'dim lavender': {'vibrant aqua': 3},
#  'dim lime': {'posh indigo': 4},
#  'dim magenta': {'wavy tan': 5},
#  'dim maroon': {'dull tan': 4},
#  'dim olive': {'clear indigo': 1, 'mirrored plum': 1, 'striped crimson': 2},
#  'dim orange': {'striped chartreuse': 2},
#  'dim plum': {'clear chartreuse': 1, 'faded brown': 3, 'vibrant turquoise': 1},
#  'dim purple': {'dim chartreuse': 2,
#                 'light black': 1,
#                 'shiny yellow': 3,
#                 'wavy crimson': 2},
#  'dim red': {'muted green': 2, 'vibrant tan': 1},
#  'dim salmon': {'mirrored yellow': 2},
#  'dim silver': {'light beige': 1, 'striped crimson': 5},
#  'dim tan': {'pale indigo': 3, 'plaid coral': 4, 'striped turquoise': 1},
#  'dim teal': {'drab plum': 2,
#               'shiny fuchsia': 4,
#               'striped gray': 3,
#               'vibrant chartreuse': 2},
#  'dim tomato': {'striped lavender': 5},
#  'dim turquoise': {'bright orange': 3, 'mirrored plum': 3, 'muted tan': 1},
#  'dim violet': {'dark purple': 5, 'dull orange': 4, 'dull turquoise': 5},
#  'dim white': {'dark cyan': 2,
#                'dark plum': 2,
#                'vibrant bronze': 5,
#                'wavy coral': 5},
#  'dim yellow': {'bright silver': 4, 'dark indigo': 4, 'muted purple': 3},
#  'dotted aqua': {'dark violet': 3,
#                  'drab plum': 4,
#                  'faded indigo': 5,
#                  'pale gray': 3},
#  'dotted beige': {'clear tan': 1},
#  'dotted black': {'dark lime': 1},
#  'dotted blue': {'dim plum': 3, 'dull cyan': 2},
#  'dotted bronze': {'light gold': 5, 'muted purple': 5, 'wavy crimson': 2},
#  'dotted brown': {'light fuchsia': 4, 'plaid cyan': 3, 'shiny brown': 5},
#  'dotted chartreuse': {'drab turquoise': 5, 'light white': 1},
#  'dotted coral': {'wavy blue': 3, 'wavy chartreuse': 2},
#  'dotted crimson': {'dark cyan': 2, 'dim chartreuse': 1, 'light red': 4},
#  'dotted cyan': {'mirrored plum': 1, 'shiny tomato': 2},
#  'dotted fuchsia': {'pale lime': 3},
#  'dotted gold': {'clear red': 3, 'striped crimson': 2},
#  'dotted gray': {'dark lime': 4,
#                  'mirrored white': 4,
#                  'vibrant coral': 5,
#                  'vibrant lavender': 3},
#  'dotted green': {'dim turquoise': 1,
#                   'dull red': 3,
#                   'faded green': 2,
#                   'muted white': 3},
#  'dotted indigo': {'shiny bronze': 4,
#                    'vibrant lavender': 5,
#                    'vibrant orange': 2},
#  'dotted lavender': {'mirrored bronze': 5,
#                      'pale crimson': 3,
#                      'plaid plum': 2,
#                      'wavy gray': 3},
#  'dotted lime': {'shiny blue': 4, 'striped fuchsia': 3},
#  'dotted magenta': {'drab gold': 5, 'muted beige': 2},
#  'dotted maroon': {'dim gold': 2,
#                    'dull lime': 4,
#                    'faded fuchsia': 2,
#                    'muted white': 5},
#  'dotted olive': {'dim yellow': 5, 'light gold': 4, 'pale aqua': 3},
#  'dotted orange': {'dotted coral': 1, 'shiny gold': 1, 'wavy coral': 3},
#  'dotted plum': {'clear red': 4},
#  'dotted purple': {'striped salmon': 4},
#  'dotted red': {'dim orange': 5, 'striped tan': 4},
#  'dotted salmon': {'mirrored lime': 2, 'mirrored salmon': 1},
#  'dotted silver': {'faded crimson': 2},
#  'dotted tan': {'striped fuchsia': 1},
#  'dotted teal': {'faded silver': 2, 'plaid coral': 3, 'shiny brown': 5},
#  'dotted tomato': {'drab yellow': 2},
#  'dotted turquoise': {'posh olive': 5},
#  'dotted violet': {'striped blue': 3},
#  'dotted white': {'bright bronze': 3, 'dark salmon': 2, 'muted plum': 3},
#  'dotted yellow': {'dark cyan': 3, 'shiny maroon': 2},
#  'drab aqua': {'dim gray': 3, 'dotted indigo': 5},
#  'drab beige': {'dark black': 3,
#                 'faded indigo': 5,
#                 'pale lime': 4,
#                 'vibrant bronze': 5},
#  'drab black': {'posh blue': 3, 'shiny brown': 3},
#  'drab blue': {'bright silver': 2, 'dim crimson': 4, 'shiny beige': 4},
#  'drab bronze': {'dim olive': 5,
#                  'dull cyan': 1,
#                  'pale green': 3,
#                  'vibrant gray': 3},
#  'drab brown': {'wavy blue': 2, 'wavy orange': 5},
#  'drab chartreuse': {'wavy orange': 2},
#  'drab coral': {'faded tomato': 2, 'plaid aqua': 3},
#  'drab crimson': {'faded purple': 5},
#  'drab cyan': {'dark fuchsia': 1,
#                'dim olive': 5,
#                'plaid beige': 4,
#                'striped salmon': 1},
#  'drab fuchsia': {'faded black': 3, 'shiny crimson': 4, 'shiny tan': 5},
#  'drab gold': {'dark maroon': 3, 'plaid beige': 2},
#  'drab gray': {'plaid indigo': 2, 'posh white': 3},
#  'drab green': {'dim orange': 3, 'vibrant chartreuse': 5},
#  'drab indigo': {'dotted green': 4, 'striped silver': 1},
#  'drab lavender': {'bright aqua': 2, 'faded lime': 5, 'pale turquoise': 4},
#  'drab lime': {'clear aqua': 3, 'shiny cyan': 4},
#  'drab magenta': {'bright gray': 5},
#  'drab maroon': {'clear silver': 5, 'faded gold': 5, 'vibrant cyan': 4},
#  'drab olive': {'dotted maroon': 3, 'striped crimson': 3},
#  'drab orange': {'dark yellow': 5,
#                  'mirrored lavender': 5,
#                  'shiny silver': 2,
#                  'vibrant indigo': 2},
#  'drab plum': {'clear gold': 3},
#  'drab purple': {'dotted blue': 2, 'muted cyan': 4, 'wavy lavender': 3},
#  'drab red': {'dark tan': 3,
#               'dotted tomato': 3,
#               'faded salmon': 5,
#               'pale red': 4},
#  'drab salmon': {'wavy silver': 4},
#  'drab silver': {'dark lime': 4, 'dull teal': 1, 'shiny cyan': 5},
#  'drab tan': {'clear crimson': 3, 'mirrored turquoise': 4, 'muted magenta': 2},
#  'drab teal': {'dark plum': 2,
#                'dim crimson': 4,
#                'dotted plum': 5,
#                'light white': 2},
#  'drab tomato': {'dull salmon': 1, 'plaid orange': 3, 'posh gray': 3},
#  'drab turquoise': 1,
#  'drab violet': {'clear gold': 1, 'clear maroon': 1, 'muted black': 4},
#  'drab white': {'drab fuchsia': 2,
#                 'dull beige': 4,
#                 'pale coral': 2,
#                 'shiny tan': 1},
#  'drab yellow': {'clear red': 5,
#                  'dark turquoise': 5,
#                  'dotted beige': 2,
#                  'muted lavender': 2},
#  'dull aqua': {'wavy coral': 2},
#  'dull beige': {'clear aqua': 5,
#                 'dark plum': 5,
#                 'posh red': 2,
#                 'vibrant turquoise': 1},
#  'dull black': {'dotted plum': 3},
#  'dull blue': {'mirrored coral': 3, 'posh coral': 4, 'striped fuchsia': 2},
#  'dull bronze': {'drab teal': 2, 'light red': 5, 'muted indigo': 4},
#  'dull brown': {'faded red': 1,
#                 'light aqua': 1,
#                 'pale aqua': 2,
#                 'wavy white': 1},
#  'dull chartreuse': {'dim salmon': 4, 'drab salmon': 5, 'vibrant red': 4},
#  'dull coral': {'dark gold': 1,
#                 'light red': 2,
#                 'striped silver': 2,
#                 'vibrant lavender': 5},
#  'dull crimson': {'dark lavender': 5, 'dark tan': 5, 'dim gold': 4},
#  'dull cyan': {'light beige': 5, 'pale gray': 3, 'striped blue': 3},
#  'dull fuchsia': {'bright orange': 1},
#  'dull gold': {'dull beige': 1},
#  'dull gray': {'dull olive': 5, 'mirrored coral': 3, 'striped lavender': 4},
#  'dull green': {'bright brown': 1,
#                 'dark silver': 1,
#                 'mirrored crimson': 5,
#                 'posh beige': 5},
#  'dull indigo': {'bright beige': 1, 'dark gold': 2, 'mirrored magenta': 1},
#  'dull lavender': {'dark tomato': 5,
#                    'drab chartreuse': 1,
#                    'shiny plum': 2,
#                    'vibrant tan': 4},
#  'dull lime': 1,
#  'dull magenta': {'dotted green': 2},
#  'dull maroon': {'mirrored fuchsia': 1},
#  'dull olive': {'dotted gold': 5,
#                 'muted gold': 3,
#                 'muted white': 4,
#                 'shiny violet': 1},
#  'dull orange': {'shiny turquoise': 1},
#  'dull plum': {'dull aqua': 5},
#  'dull purple': {'mirrored indigo': 4,
#                  'muted white': 4,
#                  'shiny crimson': 4,
#                  'wavy bronze': 2},
#  'dull red': {'clear red': 4, 'dark purple': 2, 'faded fuchsia': 1},
#  'dull salmon': {'bright white': 3, 'muted cyan': 2},
#  'dull silver': {'dark yellow': 1,
#                  'light beige': 2,
#                  'striped indigo': 3,
#                  'wavy violet': 4},
#  'dull tan': {'clear maroon': 1,
#               'dim gold': 5,
#               'posh beige': 4,
#               'striped crimson': 2},
#  'dull teal': {'vibrant yellow': 4},
#  'dull tomato': {'drab purple': 5, 'faded yellow': 4},
#  'dull turquoise': {'bright teal': 3,
#                     'clear tan': 3,
#                     'drab maroon': 1,
#                     'vibrant tomato': 1},
#  'dull violet': {'shiny tomato': 4},
#  'dull white': {'clear chartreuse': 5,
#                 'dull olive': 1,
#                 'dull red': 1,
#                 'wavy red': 1},
#  'dull yellow': {'bright lime': 4,
#                  'dotted green': 5,
#                  'faded tan': 2,
#                  'striped green': 4},
#  'faded aqua': {'clear aqua': 5, 'dim turquoise': 2, 'muted green': 3},
#  'faded beige': {'bright fuchsia': 2, 'mirrored turquoise': 2},
#  'faded black': {'posh red': 5},
#  'faded blue': {'muted tomato': 1, 'striped crimson': 4},
#  'faded bronze': {'bright aqua': 5, 'dotted chartreuse': 2, 'faded tomato': 2},
#  'faded brown': {'bright tan': 4,
#                  'clear chartreuse': 3,
#                  'dotted gold': 5,
#                  'striped turquoise': 3},
#  'faded chartreuse': {'mirrored white': 2},
#  'faded coral': {'light chartreuse': 1, 'muted tomato': 3},
#  'faded crimson': {'light blue': 3, 'pale aqua': 5},
#  'faded cyan': {'dull crimson': 2, 'light chartreuse': 4, 'light salmon': 4},
#  'faded fuchsia': 1,
#  'faded gold': {'plaid aqua': 5},
#  'faded gray': {'mirrored yellow': 2, 'plaid white': 4},
#  'faded green': {'dotted plum': 4, 'light white': 1},
#  'faded indigo': {'faded green': 4},
#  'faded lavender': {'dull cyan': 5},
#  'faded lime': {'bright tan': 1},
#  'faded magenta': {'dim maroon': 1, 'dotted beige': 1, 'mirrored gray': 3},
#  'faded maroon': {'dim chartreuse': 3,
#                   'light aqua': 2,
#                   'striped indigo': 5,
#                   'vibrant tomato': 4},
#  'faded olive': {'pale gray': 3, 'posh fuchsia': 5, 'shiny lavender': 2},
#  'faded orange': {'drab beige': 4, 'plaid orange': 2, 'vibrant salmon': 1},
#  'faded plum': {'dull tan': 4, 'shiny tan': 2},
#  'faded purple': {'dark indigo': 3,
#                   'mirrored indigo': 2,
#                   'muted olive': 5,
#                   'pale fuchsia': 2},
#  'faded red': {'clear beige': 4, 'dim silver': 3, 'posh gray': 4},
#  'faded salmon': {'bright silver': 1},
#  'faded silver': {'dark cyan': 1,
#                   'dark plum': 1,
#                   'dotted plum': 5,
#                   'dull red': 5},
#  'faded tan': {'dark lime': 4,
#                'dim green': 4,
#                'mirrored violet': 1,
#                'muted green': 4},
#  'faded teal': {'light black': 2, 'vibrant maroon': 1},
#  'faded tomato': {'dotted green': 4, 'striped bronze': 1},
#  'faded turquoise': {'clear lavender': 3, 'dull coral': 3, 'light lavender': 2},
#  'faded violet': {'shiny gold': 2},
#  'faded white': {'dotted orange': 4, 'striped lime': 3},
#  'faded yellow': {'dark purple': 1,
#                   'plaid bronze': 2,
#                   'shiny crimson': 5,
#                   'shiny tan': 3},
#  'light aqua': {'dotted black': 3,
#                 'mirrored magenta': 4,
#                 'muted tomato': 4,
#                 'posh maroon': 3},
#  'light beige': {'dark cyan': 3, 'striped crimson': 3},
#  'light black': {'clear tan': 4,
#                  'dim fuchsia': 3,
#                  'pale indigo': 3,
#                  'wavy lime': 5},
#  'light blue': {'clear chartreuse': 3, 'dull olive': 5},
#  'light bronze': {'bright gray': 4,
#                   'clear silver': 2,
#                   'light tomato': 3,
#                   'shiny white': 2},
#  'light brown': {'clear gold': 1},
#  'light chartreuse': {'mirrored violet': 1, 'striped lavender': 5},
#  'light coral': {'bright beige': 1,
#                  'dull aqua': 2,
#                  'posh tan': 3,
#                  'wavy maroon': 4},
#  'light crimson': {'bright silver': 3, 'dark lime': 2},
#  'light cyan': {'faded violet': 2,
#                 'light tomato': 3,
#                 'pale black': 3,
#                 'pale brown': 5},
#  'light fuchsia': {'faded green': 1,
#                    'muted black': 5,
#                    'muted white': 4,
#                    'wavy silver': 2},
#  'light gold': {'clear red': 5},
#  'light gray': {'dotted maroon': 5, 'mirrored violet': 4, 'pale lime': 3},
#  'light green': {'plaid plum': 2},
#  'light indigo': {'faded red': 3,
#                   'shiny crimson': 2,
#                   'striped coral': 2,
#                   'wavy green': 3},
#  'light lavender': {'dark maroon': 4,
#                     'dotted violet': 4,
#                     'dull violet': 3,
#                     'striped violet': 2},
#  'light lime': {'dark fuchsia': 5, 'dotted salmon': 4, 'vibrant indigo': 2},
#  'light magenta': {'shiny turquoise': 2},
#  'light maroon': {'faded silver': 5},
#  'light olive': {'clear orange': 3,
#                  'dotted plum': 3,
#                  'posh turquoise': 3,
#                  'shiny white': 1},
#  'light orange': {'dotted teal': 4, 'dotted yellow': 4},
#  'light plum': {'drab brown': 3, 'vibrant lavender': 3, 'wavy cyan': 4},
#  'light purple': {'mirrored lime': 1},
#  'light red': {'dotted teal': 4, 'mirrored lime': 1, 'mirrored magenta': 5},
#  'light salmon': {'bright orange': 2, 'dark blue': 1},
#  'light silver': {'clear aqua': 2,
#                   'light salmon': 1,
#                   'mirrored plum': 4,
#                   'striped silver': 2},
#  'light tan': {'dim white': 4, 'shiny violet': 4, 'striped turquoise': 4},
#  'light teal': {'light lavender': 4},
#  'light tomato': {'dim green': 3,
#                   'mirrored magenta': 4,
#                   'muted gold': 1,
#                   'posh fuchsia': 3},
#  'light turquoise': {'dim chartreuse': 4, 'dim plum': 4, 'wavy blue': 3},
#  'light violet': {'dim plum': 5, 'drab teal': 3, 'muted violet': 4},
#  'light white': 1,
#  'light yellow': {'wavy turquoise': 3},
#  'mirrored aqua': {'dark gold': 2, 'shiny green': 2},
#  'mirrored beige': {'muted white': 1},
#  'mirrored black': {'light fuchsia': 5, 'muted yellow': 4},
#  'mirrored blue': {'dark lavender': 4, 'posh magenta': 3, 'striped crimson': 5},
#  'mirrored bronze': {'wavy turquoise': 1},
#  'mirrored brown': {'bright bronze': 4,
#                     'dotted crimson': 5,
#                     'light bronze': 1,
#                     'shiny chartreuse': 2},
#  'mirrored chartreuse': {'drab beige': 4, 'pale indigo': 1},
#  'mirrored coral': {'dark indigo': 4},
#  'mirrored crimson': {'dotted gold': 2, 'shiny red': 5, 'wavy red': 5},
#  'mirrored cyan': {'drab olive': 2, 'mirrored salmon': 4},
#  'mirrored fuchsia': {'dotted green': 1, 'plaid cyan': 1},
#  'mirrored gold': {'dotted maroon': 2},
#  'mirrored gray': {'dim silver': 5, 'mirrored plum': 1},
#  'mirrored green': {'bright tan': 2, 'dim cyan': 4},
#  'mirrored indigo': {'faded blue': 3, 'shiny tan': 4},
#  'mirrored lavender': {'plaid bronze': 4, 'wavy chartreuse': 4},
#  'mirrored lime': {'dotted plum': 5, 'muted tomato': 4, 'wavy chartreuse': 5},
#  'mirrored magenta': {'dotted plum': 4, 'posh beige': 3},
#  'mirrored maroon': {'light aqua': 3},
#  'mirrored olive': {'clear blue': 1, 'dark lavender': 5},
#  'mirrored orange': {'dotted olive': 4, 'plaid lime': 5},
#  'mirrored plum': {'dull red': 2, 'muted magenta': 3},
#  'mirrored purple': {'light magenta': 1,
#                      'shiny yellow': 3,
#                      'striped lavender': 4},
#  'mirrored red': {'bright violet': 5,
#                   'muted aqua': 4,
#                   'pale salmon': 4,
#                   'shiny tan': 4},
#  'mirrored salmon': {'clear aqua': 4, 'faded crimson': 1, 'muted gold': 3},
#  'mirrored silver': {'dotted chartreuse': 2,
#                      'dotted fuchsia': 1,
#                      'mirrored lavender': 4,
#                      'mirrored white': 2},
#  'mirrored tan': {'dark silver': 2, 'dim tan': 3, 'posh gray': 3},
#  'mirrored teal': {'dark lime': 4,
#                    'dim teal': 5,
#                    'mirrored turquoise': 3,
#                    'mirrored yellow': 4},
#  'mirrored tomato': {'drab tomato': 5, 'plaid bronze': 1},
#  'mirrored turquoise': {'drab turquoise': 2, 'faded chartreuse': 3},
#  'mirrored violet': {'mirrored white': 5},
#  'mirrored white': {'dim plum': 5, 'mirrored magenta': 3},
#  'mirrored yellow': {'dotted plum': 1},
#  'muted aqua': {'bright cyan': 3, 'striped purple': 2, 'vibrant orange': 3},
#  'muted beige': {'shiny lavender': 1, 'striped chartreuse': 1},
#  'muted black': {'clear red': 3, 'dotted maroon': 3},
#  'muted blue': {'bright lavender': 2, 'dark beige': 3, 'dull teal': 5},
#  'muted bronze': {'clear chartreuse': 4, 'drab turquoise': 4, 'pale coral': 3},
#  'muted brown': {'clear purple': 4,
#                  'dark blue': 4,
#                  'drab magenta': 1,
#                  'vibrant plum': 2},
#  'muted chartreuse': {'bright tan': 4, 'faded black': 1, 'muted bronze': 3},
#  'muted coral': {'dark violet': 1, 'striped bronze': 2},
#  'muted crimson': {'muted silver': 4,
#                    'posh beige': 3,
#                    'shiny lavender': 5,
#                    'shiny purple': 2},
#  'muted cyan': {'clear aqua': 4},
#  'muted fuchsia': {'vibrant red': 3},
#  'muted gold': {'pale coral': 4},
#  'muted gray': {'shiny tomato': 3},
#  'muted green': {'bright white': 5, 'dim gold': 5},
#  'muted indigo': {'dull beige': 3, 'mirrored orange': 1},
#  'muted lavender': {'dim chartreuse': 1,
#                     'dull fuchsia': 4,
#                     'shiny beige': 2,
#                     'vibrant gold': 1},
#  'muted lime': {'dull teal': 2},
#  'muted magenta': 1,
#  'muted maroon': {'dark fuchsia': 5, 'dim salmon': 5, 'muted red': 2},
#  'muted olive': {'dotted black': 3, 'vibrant tan': 4},
#  'muted orange': {'dotted teal': 2,
#                   'dull yellow': 3,
#                   'plaid tan': 3,
#                   'vibrant blue': 1},
#  'muted plum': {'muted turquoise': 2,
#                 'striped blue': 3,
#                 'striped gray': 3,
#                 'wavy lavender': 5},
#  'muted purple': {'bright tan': 3, 'light beige': 3},
#  'muted red': {'clear cyan': 4, 'light tan': 3},
#  'muted salmon': {'dotted black': 1, 'faded brown': 4, 'muted black': 5},
#  'muted silver': {'bright blue': 3,
#                   'bright tan': 1,
#                   'muted bronze': 5,
#                   'shiny blue': 1},
#  'muted tan': {'faded green': 3},
#  'muted teal': {'plaid turquoise': 5, 'wavy green': 5},
#  'muted tomato': {'bright tan': 4,
#                   'dark plum': 3,
#                   'faded green': 5,
#                   'striped blue': 4},
#  'muted turquoise': {'light purple': 3,
#                      'plaid cyan': 4,
#                      'shiny maroon': 2,
#                      'striped tan': 2},
#  'muted violet': {'shiny beige': 5, 'vibrant blue': 5},
#  'muted white': 1,
#  'muted yellow': {'drab olive': 3,
#                   'pale lime': 4,
#                   'striped crimson': 2,
#                   'wavy blue': 3},
#  'pale aqua': {'posh beige': 3},
#  'pale beige': {'dark plum': 5,
#                 'dark purple': 2,
#                 'dim turquoise': 2,
#                 'wavy indigo': 3},
#  'pale black': {'clear maroon': 5, 'dark gold': 4, 'striped crimson': 4},
#  'pale blue': {'bright cyan': 1,
#                'dotted silver': 5,
#                'shiny fuchsia': 1,
#                'wavy turquoise': 5},
#  'pale bronze': {'dotted fuchsia': 5, 'muted tan': 4},
#  'pale brown': {'dark tomato': 4,
#                 'drab coral': 1,
#                 'mirrored lavender': 2,
#                 'plaid indigo': 3},
#  'pale chartreuse': {'clear turquoise': 5, 'muted maroon': 1, 'wavy teal': 1},
#  'pale coral': {'dim gold': 5, 'vibrant bronze': 1},
#  'pale crimson': {'dotted orange': 4, 'faded silver': 2},
#  'pale cyan': {'light salmon': 3,
#                'striped cyan': 4,
#                'vibrant orange': 4,
#                'wavy gray': 4},
#  'pale fuchsia': {'dark gold': 5, 'dull crimson': 4, 'wavy red': 3},
#  'pale gold': {'clear bronze': 5,
#                'faded green': 4,
#                'muted cyan': 3,
#                'vibrant aqua': 5},
#  'pale gray': {'bright blue': 3, 'muted tan': 5},
#  'pale green': {'dim plum': 4, 'shiny purple': 1},
#  'pale indigo': {'drab magenta': 5,
#                  'mirrored black': 1,
#                  'plaid brown': 4,
#                  'plaid cyan': 1},
#  'pale lavender': {'shiny violet': 2},
#  'pale lime': {'dotted maroon': 4, 'faded silver': 2, 'shiny tomato': 5},
#  'pale magenta': {'dotted fuchsia': 1, 'muted salmon': 3, 'vibrant black': 5},
#  'pale maroon': {'bright gray': 1, 'muted tan': 3},
#  'pale olive': {'plaid cyan': 2},
#  'pale orange': {'muted green': 5},
#  'pale plum': {'dull coral': 5, 'shiny silver': 5},
#  'pale purple': {'clear orange': 1, 'shiny olive': 2, 'vibrant coral': 1},
#  'pale red': {'vibrant turquoise': 1},
#  'pale salmon': {'mirrored white': 5},
#  'pale silver': {'faded coral': 1, 'shiny lavender': 5, 'wavy lime': 5},
#  'pale tan': {'dark brown': 5,
#               'drab blue': 5,
#               'light gold': 5,
#               'wavy black': 1},
#  'pale teal': {'dim coral': 3,
#                'plaid silver': 5,
#                'shiny turquoise': 4,
#                'vibrant bronze': 2},
#  'pale tomato': {'light gold': 2},
#  'pale turquoise': {'clear gold': 2, 'dull white': 1, 'muted tomato': 1},
#  'pale violet': {'drab teal': 3,
#                  'light plum': 1,
#                  'striped silver': 3,
#                  'wavy purple': 1},
#  'pale white': {'shiny beige': 3},
#  'pale yellow': {'dark chartreuse': 2,
#                  'dim crimson': 2,
#                  'posh silver': 4,
#                  'wavy gold': 3},
#  'plaid aqua': {'mirrored gray': 2, 'shiny maroon': 4},
#  'plaid beige': {'faded violet': 3, 'shiny violet': 2},
#  'plaid black': {'dull olive': 4, 'mirrored white': 4, 'plaid white': 4},
#  'plaid blue': {'mirrored blue': 4, 'plaid olive': 1},
#  'plaid bronze': {'wavy indigo': 3},
#  'plaid brown': {'dotted yellow': 4},
#  'plaid chartreuse': {'dim indigo': 4, 'dim lime': 4, 'mirrored gold': 4},
#  'plaid coral': {'dark purple': 5, 'light beige': 4, 'striped crimson': 5},
#  'plaid crimson': {'bright brown': 5, 'dim olive': 1, 'dull lavender': 5},
#  'plaid cyan': {'pale aqua': 2,
#                 'plaid yellow': 5,
#                 'shiny brown': 5,
#                 'striped turquoise': 3},
#  'plaid fuchsia': {'bright coral': 5, 'dim cyan': 2},
#  'plaid gold': {'drab tomato': 5},
#  'plaid gray': {'dotted cyan': 5, 'mirrored silver': 2},
#  'plaid green': {'dark blue': 5, 'dark chartreuse': 5, 'wavy cyan': 3},
#  'plaid indigo': {'dull lime': 4, 'faded violet': 3},
#  'plaid lavender': {'dim lavender': 3, 'dotted salmon': 3},
#  'plaid lime': {'drab brown': 3, 'drab teal': 1, 'light blue': 3},
#  'plaid magenta': {'light fuchsia': 3},
#  'plaid maroon': {'dark teal': 1,
#                   'shiny white': 4,
#                   'striped coral': 5,
#                   'vibrant white': 4},
#  'plaid olive': {'bright lavender': 2, 'shiny white': 3},
#  'plaid orange': {'dark lime': 3},
#  'plaid plum': {'bright bronze': 3},
#  'plaid purple': {'muted lime': 4},
#  'plaid red': {'dim brown': 1,
#                'muted plum': 1,
#                'vibrant plum': 2,
#                'wavy gold': 5},
#  'plaid salmon': {'faded lime': 1},
#  'plaid silver': {'dark purple': 3,
#                   'dull lavender': 5,
#                   'muted olive': 5,
#                   'vibrant bronze': 1},
#  'plaid tan': {'clear silver': 2, 'dotted maroon': 1, 'light chartreuse': 5},
#  'plaid teal': {'dark indigo': 3, 'plaid fuchsia': 4, 'vibrant teal': 1},
#  'plaid tomato': {'wavy orange': 4},
#  'plaid turquoise': {'dim lime': 3},
#  'plaid violet': {'dim turquoise': 2, 'vibrant indigo': 2},
#  'plaid white': {'pale tomato': 1,
#                  'posh magenta': 2,
#                  'shiny fuchsia': 5,
#                  'vibrant maroon': 5},
#  'plaid yellow': {'striped lime': 4, 'striped turquoise': 1},
#  'posh aqua': {'drab chartreuse': 3, 'plaid violet': 5},
#  'posh beige': {'dim gold': 3, 'faded silver': 3, 'shiny gold': 5},
#  'posh black': {'drab coral': 5, 'dull violet': 3},
#  'posh blue': {'bright silver': 2, 'dim salmon': 2, 'drab beige': 4},
#  'posh bronze': {'drab olive': 4,
#                  'light silver': 5,
#                  'mirrored green': 2,
#                  'shiny maroon': 1},
#  'posh brown': {'muted beige': 2},
#  'posh chartreuse': {'clear maroon': 3, 'vibrant white': 3, 'wavy black': 4},
#  'posh coral': {'dotted red': 3, 'drab silver': 1, 'shiny green': 3},
#  'posh crimson': {'bright blue': 5,
#                   'bright magenta': 2,
#                   'mirrored purple': 2,
#                   'striped silver': 1},
#  'posh cyan': {'dull lime': 3,
#                'faded blue': 4,
#                'shiny blue': 3,
#                'vibrant magenta': 2},
#  'posh fuchsia': {'dim cyan': 4, 'dotted plum': 4, 'vibrant turquoise': 4},
#  'posh gold': {'clear blue': 5},
#  'posh gray': {'clear yellow': 3,
#                'muted crimson': 4,
#                'striped crimson': 3,
#                'striped turquoise': 1},
#  'posh green': {'bright yellow': 5,
#                 'mirrored blue': 3,
#                 'vibrant yellow': 4,
#                 'wavy fuchsia': 2},
#  'posh indigo': {'dull lime': 1, 'faded silver': 1, 'striped lavender': 4},
#  'posh lavender': {'faded aqua': 4, 'light red': 2, 'mirrored aqua': 2},
#  'posh lime': {'dotted teal': 3, 'shiny cyan': 5, 'wavy violet': 1},
#  'posh magenta': {'bright gray': 4, 'dotted turquoise': 4},
#  'posh maroon': {'light bronze': 1, 'muted tan': 4, 'vibrant plum': 5},
#  'posh olive': {'dark plum': 3, 'muted magenta': 3, 'shiny violet': 1},
#  'posh orange': {'light blue': 4},
#  'posh plum': {'dotted orange': 2,
#                'dull cyan': 5,
#                'light beige': 5,
#                'plaid indigo': 3},
#  'posh purple': {'wavy purple': 5},
#  'posh red': {'dark black': 1,
#               'dark purple': 5,
#               'drab olive': 3,
#               'striped lavender': 2},
#  'posh salmon': {'dark salmon': 3, 'dim yellow': 5, 'posh purple': 2},
#  'posh silver': {'bright lavender': 4,
#                  'dull crimson': 2,
#                  'light gold': 5,
#                  'posh beige': 2},
#  'posh tan': {'dark brown': 4, 'drab crimson': 1},
#  'posh teal': {'drab salmon': 3,
#                'pale gray': 2,
#                'shiny plum': 3,
#                'striped gold': 4},
#  'posh tomato': {'drab blue': 5},
#  'posh turquoise': {'dotted blue': 3, 'mirrored fuchsia': 1, 'pale lime': 4},
#  'posh violet': {'dark blue': 1, 'muted fuchsia': 4, 'shiny indigo': 1},
#  'posh white': {'dotted turquoise': 4, 'mirrored lime': 1},
#  'posh yellow': {'dark black': 2, 'dim teal': 4},
#  'shiny aqua': {'bright maroon': 5, 'dotted salmon': 5, 'wavy red': 1},
#  'shiny beige': {'dotted yellow': 3, 'muted tomato': 2, 'wavy red': 4},
#  'shiny black': {'dull crimson': 2},
#  'shiny blue': {'dotted plum': 2, 'wavy coral': 2},
#  'shiny bronze': {'bright olive': 4,
#                   'mirrored blue': 3,
#                   'pale lavender': 5,
#                   'plaid bronze': 3},
#  'shiny brown': {'bright orange': 5,
#                  'light beige': 1,
#                  'muted tan': 1,
#                  'striped blue': 4},
#  'shiny chartreuse': {'bright yellow': 5},
#  'shiny coral': {'dark blue': 5, 'dark yellow': 2, 'dotted green': 4},
#  'shiny crimson': {'dark lavender': 4, 'dark tan': 3, 'dotted gold': 3},
#  'shiny cyan': {'mirrored aqua': 1, 'mirrored gold': 1, 'posh magenta': 1},
#  'shiny fuchsia': {'drab fuchsia': 2,
#                    'dull aqua': 2,
#                    'muted black': 1,
#                    'shiny cyan': 1},
#  'shiny gold': {'dull lime': 1,
#                 'muted black': 5,
#                 'pale coral': 2,
#                 'wavy silver': 1},
#  'shiny gray': {'plaid chartreuse': 3},
#  'shiny green': {'dark plum': 4,
#                  'dim plum': 3,
#                  'drab fuchsia': 4,
#                  'mirrored gold': 3},
#  'shiny indigo': {'dull lavender': 3},
#  'shiny lavender': {'light fuchsia': 2},
#  'shiny lime': {'drab coral': 3, 'drab green': 1, 'muted salmon': 4},
#  'shiny magenta': {'dark tomato': 2,
#                    'dotted gray': 3,
#                    'faded silver': 3,
#                    'shiny blue': 1},
#  'shiny maroon': {'light beige': 5, 'light white': 3},
#  'shiny olive': {'mirrored gray': 2, 'plaid beige': 5, 'striped salmon': 4},
#  'shiny orange': {'drab chartreuse': 3, 'shiny gold': 1},
#  'shiny plum': {'clear gold': 1, 'dotted blue': 2},
#  'shiny purple': {'dark indigo': 1,
#                   'dotted green': 5,
#                   'plaid fuchsia': 4,
#                   'posh beige': 1},
#  'shiny red': {'bright aqua': 2, 'bright gray': 2, 'drab blue': 4},
#  'shiny salmon': {'clear turquoise': 4, 'posh magenta': 2, 'shiny tan': 5},
#  'shiny silver': {'dim yellow': 2, 'wavy coral': 1},
#  'shiny tan': {'dark lavender': 5,
#                'dull red': 1,
#                'faded fuchsia': 5,
#                'vibrant turquoise': 4},
#  'shiny teal': {'pale indigo': 5},
#  'shiny tomato': {'faded green': 3,
#                   'muted tomato': 3,
#                   'striped blue': 2,
#                   'wavy green': 5},
#  'shiny turquoise': {'bright lavender': 4, 'dark tan': 4, 'muted bronze': 5},
#  'shiny violet': {'dark cyan': 2, 'dull lime': 4, 'muted white': 4},
#  'shiny white': {'mirrored violet': 1},
#  'shiny yellow': {'light fuchsia': 4, 'mirrored plum': 2},
#  'striped aqua': {'dim crimson': 3},
#  'striped beige': {'pale gray': 4,
#                    'shiny yellow': 2,
#                    'striped bronze': 2,
#                    'vibrant tomato': 2},
#  'striped black': {'dull white': 5},
#  'striped blue': {'dull lime': 2, 'light white': 5, 'shiny maroon': 1},
#  'striped bronze': {'dim chartreuse': 5, 'shiny violet': 1},
#  'striped brown': {'bright lime': 4, 'wavy coral': 5},
#  'striped chartreuse': {'dull tan': 4, 'mirrored plum': 4, 'muted gold': 5},
#  'striped coral': {'dark purple': 1, 'shiny red': 1},
#  'striped crimson': 1,
#  'striped cyan': {'bright coral': 1, 'dotted plum': 1},
#  'striped fuchsia': {'dim plum': 3, 'shiny white': 4, 'striped black': 1},
#  'striped gold': {'shiny crimson': 1},
#  'striped gray': {'bright orange': 5, 'clear chartreuse': 2, 'muted white': 5},
#  'striped green': {'posh indigo': 5},
#  'striped indigo': {'mirrored blue': 5,
#                     'striped violet': 2,
#                     'striped yellow': 3},
#  'striped lavender': {'striped blue': 2},
#  'striped lime': {'dim gold': 4, 'mirrored plum': 4, 'pale coral': 5},
#  'striped magenta': {'dark plum': 5, 'faded bronze': 5, 'striped brown': 4},
#  'striped maroon': {'muted lime': 1},
#  'striped olive': {'dull lime': 5},
#  'striped orange': {'plaid plum': 3},
#  'striped plum': {'dim crimson': 3,
#                   'drab white': 2,
#                   'mirrored yellow': 2,
#                   'pale salmon': 2},
#  'striped purple': {'clear chartreuse': 2,
#                     'dark cyan': 4,
#                     'striped chartreuse': 2,
#                     'striped salmon': 5},
#  'striped red': {'bright orange': 2,
#                  'clear aqua': 3,
#                  'dotted coral': 1,
#                  'mirrored yellow': 3},
#  'striped salmon': {'dim plum': 2, 'mirrored indigo': 2},
#  'striped silver': {'dull lime': 4, 'striped blue': 5},
#  'striped tan': {'bright gray': 4,
#                  'plaid cyan': 1,
#                  'vibrant magenta': 1,
#                  'wavy gray': 2},
#  'striped teal': {'dark violet': 1,
#                   'dotted yellow': 5,
#                   'mirrored crimson': 5,
#                   'mirrored violet': 1},
#  'striped tomato': {'dim plum': 4, 'drab black': 4, 'striped black': 1},
#  'striped turquoise': {'bright orange': 3,
#                        'clear red': 1,
#                        'plaid coral': 5,
#                        'wavy silver': 3},
#  'striped violet': {'clear beige': 1, 'dim indigo': 2, 'muted lime': 3},
#  'striped white': {'clear olive': 2,
#                    'dark gold': 3,
#                    'dotted bronze': 1,
#                    'posh tomato': 3},
#  'striped yellow': {'vibrant crimson': 2},
#  'vibrant aqua': {'bright coral': 5, 'drab tan': 3, 'pale brown': 3},
#  'vibrant beige': {'dull fuchsia': 2},
#  'vibrant black': {'dotted green': 4, 'light brown': 2},
#  'vibrant blue': {'bright beige': 4, 'bright bronze': 5, 'plaid salmon': 2},
#  'vibrant bronze': {'faded silver': 5, 'mirrored plum': 4},
#  'vibrant brown': {'shiny violet': 5},
#  'vibrant chartreuse': {'dark lime': 3,
#                         'dull gray': 1,
#                         'mirrored turquoise': 1,
#                         'vibrant indigo': 2},
#  'vibrant coral': {'muted gray': 2, 'shiny blue': 2},
#  'vibrant crimson': {'muted lime': 2, 'plaid indigo': 5},
#  'vibrant cyan': {'vibrant lavender': 5},
#  'vibrant fuchsia': {'dark gold': 5,
#                      'dim cyan': 5,
#                      'dull orange': 1,
#                      'light white': 4},
#  'vibrant gold': {'mirrored gold': 5, 'shiny tan': 3},
#  'vibrant gray': {'drab aqua': 3, 'faded turquoise': 3, 'pale black': 5},
#  'vibrant green': {'dark plum': 1},
#  'vibrant indigo': {'bright aqua': 1, 'drab teal': 5},
#  'vibrant lavender': {'dotted plum': 2, 'faded fuchsia': 1, 'shiny blue': 2},
#  'vibrant lime': {'clear purple': 4, 'pale silver': 2, 'striped crimson': 4},
#  'vibrant magenta': {'muted gray': 3},
#  'vibrant maroon': {'mirrored fuchsia': 4},
#  'vibrant olive': {'faded blue': 1,
#                    'shiny beige': 4,
#                    'striped gold': 4,
#                    'vibrant beige': 1},
#  'vibrant orange': {'bright olive': 2, 'vibrant olive': 3, 'wavy violet': 3},
#  'vibrant plum': {'dotted teal': 3, 'vibrant gold': 5},
#  'vibrant purple': {'dull crimson': 2, 'pale gray': 2},
#  'vibrant red': {'drab teal': 3,
#                  'faded indigo': 2,
#                  'light chartreuse': 3,
#                  'striped indigo': 1},
#  'vibrant salmon': {'light maroon': 5, 'pale green': 1, 'striped violet': 4},
#  'vibrant silver': {'dark black': 1, 'drab tan': 2},
#  'vibrant tan': {'vibrant bronze': 1},
#  'vibrant teal': {'dim gray': 3, 'faded tomato': 1},
#  'vibrant tomato': {'pale fuchsia': 5, 'plaid coral': 5},
#  'vibrant turquoise': {'dark lavender': 3,
#                        'dark plum': 5,
#                        'dark purple': 5,
#                        'striped crimson': 4},
#  'vibrant violet': {'faded orange': 4, 'plaid indigo': 2},
#  'vibrant white': {'bright blue': 3, 'dim gold': 2, 'striped violet': 5},
#  'vibrant yellow': {'dotted cyan': 1, 'posh silver': 3},
#  'wavy aqua': {'bright gray': 1, 'dim lime': 4, 'dotted bronze': 4},
#  'wavy beige': {'bright white': 3,
#                 'dotted beige': 3,
#                 'dull magenta': 3,
#                 'striped fuchsia': 2},
#  'wavy black': {'dim crimson': 5, 'dotted chartreuse': 5},
#  'wavy blue': {'posh olive': 5, 'striped blue': 5},
#  'wavy bronze': {'bright white': 1, 'plaid lime': 1, 'plaid yellow': 4},
#  'wavy brown': {'drab white': 4,
#                 'light maroon': 4,
#                 'posh teal': 5,
#                 'shiny chartreuse': 5},
#  'wavy chartreuse': {'dotted yellow': 3},
#  'wavy coral': {'dim gold': 3,
#                 'dim silver': 4,
#                 'faded green': 4,
#                 'muted purple': 2},
#  'wavy crimson': {'mirrored orange': 1},
#  'wavy cyan': {'bright yellow': 1, 'light orange': 3, 'pale fuchsia': 2},
#  'wavy fuchsia': {'faded fuchsia': 3, 'light beige': 2},
#  'wavy gold': {'drab brown': 3, 'drab olive': 1, 'shiny cyan': 1},
#  'wavy gray': {'pale lime': 5, 'shiny violet': 3, 'striped silver': 2},
#  'wavy green': {'shiny crimson': 3},
#  'wavy indigo': {'light fuchsia': 1},
#  'wavy lavender': {'muted white': 5},
#  'wavy lime': {'faded silver': 4, 'vibrant coral': 3, 'vibrant gold': 3},
#  'wavy magenta': {'bright yellow': 3,
#                   'shiny maroon': 3,
#                   'wavy orange': 1,
#                   'wavy purple': 5},
#  'wavy maroon': {'pale red': 1,
#                  'plaid bronze': 4,
#                  'striped yellow': 5,
#                  'vibrant white': 3},
#  'wavy olive': {'dotted cyan': 4},
#  'wavy orange': {'bright tan': 2, 'light beige': 5, 'vibrant turquoise': 2},
#  'wavy plum': {'bright lavender': 3,
#                'drab chartreuse': 2,
#                'dull olive': 5,
#                'faded aqua': 4},
#  'wavy purple': {'dim chartreuse': 3},
#  'wavy red': {'dark plum': 1,
#               'light white': 4,
#               'striped blue': 3,
#               'wavy silver': 1},
#  'wavy salmon': {'drab bronze': 5, 'light maroon': 4},
#  'wavy silver': {'vibrant bronze': 1},
#  'wavy tan': {'clear beige': 3, 'dotted gold': 2, 'shiny yellow': 2},
#  'wavy teal': {'dotted cyan': 4,
#                'dull black': 5,
#                'striped teal': 3,
#                'vibrant olive': 5},
#  'wavy tomato': {'dark gold': 3,
#                  'light orange': 1,
#                  'muted olive': 2,
#                  'muted salmon': 4},
#  'wavy turquoise': {'shiny yellow': 5},
#  'wavy violet': {'clear tan': 1, 'dotted gray': 2, 'plaid brown': 5},
#  'wavy white': {'striped red': 2},
#  'wavy yellow': {'dotted cyan': 3}}

# %%
list_all = list(big_dict['shiny gold'].values())
i = 0
def count_bags(dict_=big_dict['shiny gold']):
    global list_all, i
    keys = dict_.keys()
    values = list(dict_.values())
    print(values)
#     i = 0
#     list_all[i] = 
    for key in keys:
        i += 1
        new_dict = big_dict[key]
        while type(new_dict) is not int:
            value = dict_[key]
            count_bags(dict_ = new_dict)
        print(new_dict)

# %%
big_dict['shiny gold']
# Out:
# {'dull lime': 1, 'pale coral': 2, 'wavy silver': 1, 'muted black': 5}

# %%
big_dict['pale coral']
# Out:
# {'dim gold': 5, 'vibrant bronze': 1}

# %%
big_dict['dim gold']
# Out:
# 1

# %%
big_dict['vibrant bronze']
# Out:
# {'mirrored plum': 4, 'faded silver': 5}

# %%
big_dict['mirrored plum']
# Out:
# {'dull red': 2, 'muted magenta': 3}

# %%
big_dict['dull red']
# Out:
# {'faded fuchsia': 1, 'dark purple': 2, 'clear red': 4}

# %%
big_dict['faded fuchsia']
# Out:
# 1

# %%
big_dict['dark purple']
# Out:
# {'dark cyan': 5}

# %%
big_dict['dark cyan']
# Out:
# 1

# %%
big_dict['clear red']
# Out:
# 1

# %%
def count_bags(dict_=big_dict['shiny gold']):
    global list_all, i
    keys = dict_.keys()
    values = list(dict_.values())
    print(values)
#     i = 0
#     list_all[i] = 
    for key in keys:
        i += 1
        new_dict = big_dict[key]
        if type(new_dict) is not int:
            value = dict_[key]
            count_bags(dict_ = new_dict)
        print(new_dict)
